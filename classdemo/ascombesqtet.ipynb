# %% [markdown]
# <a href="https://colab.research.google.com/github/fedhere/PUS2022_FBianco/blob/main/classdemo/ascombesqtet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Author: FBB
#
# ### This is a demo of the famous Anscombe's Quartet
# ### developed BY Federica B Bianco, UD @fedhere
# ### for CUSP Principle of Urban Informatics.
#
# ## The moral of the story is: look at your data!
# ### version 1: August 2015
# ### last update: September 2022

# %%
import os
import numpy as np
import pylab as pl
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### lets read in a file which is not a regular csv file, called anscombe.txt, but let's use the pandas moduleand its read_csv function

# %%
import pandas as pd
pd.read_csv("https://raw.githubusercontent.com/fedhere/PUS2020_FBianco/master/data/anscombe.txt")
# Out:
#                               Anscombe's Quartet
# 0         Anscombe-Data-Set I I II II III III IV IV
# 1                                   X Y X Y X Y X Y
# 2                    10 8.04 10 9.14 10 7.46 8 6.58
# 3                       8 6.95 8 8.14 8 6.77 8 5.76
# 4                   13 7.58 13 8.74 13 12.74 8 7.71
# 5                       9 8.81 9 8.77 9 7.11 8 8.84
# 6                    11 8.33 11 9.26 11 7.81 8 8.47
# 7                     14 9.96 14 8.1 14 8.84 8 7.04
# 8                       6 7.24 6 6.13 6 6.08 8 5.25
# 9                       4 4.26 4 3.1 4 5.39 19 12.5
# 10                  12 10.84 12 9.13 12 8.15 8 5.56
# 11                      7 4.82 7 7.26 7 6.42 8 7.91
# 12                      5 5.68 5 4.74 5 5.73 8 6.89
# 13      9.00 7.50 9.00 7.50 9.00 7.50 9.00 7.50 Mean
# 14   10.00 3.75 10.00 3.75 10.00 3.75 10.00 3.75 V...
# 15   0.816  0.816  0.816  0.817  Correlation (Pear...

# %% [markdown]
# notice that I used the link to github starting with raw: https://raw.githubusercontent.com/fedhere/UInotebooks/master/anscombe.txt. The page https://github.com/fedhere/UInotebooks/blob/master/anscombe.txt is an html file hosting the text for rendering. Downloading that would download an html file. Try it.

# %% [markdown]
# ## pandas organizes datasets in "data frames"
#
# ## lets read the file a little better by identifying what to use as header to name our variables

# %%
pd.read_csv("https://raw.githubusercontent.com/fedhere/PUS2020_FBianco/master/data/anscombe.txt", 
            header = [1, 2], delimiter=' ')
# Out:
#     Anscombe-Data-Set       I             II           III             IV  \
#    Unnamed: 0_level_1       X      Y       X     Y       X      Y       X
# 0                 NaN  10.000   8.04  10.000  9.14  10.000   7.46   8.000
# 1                 NaN   8.000   6.95   8.000  8.14   8.000   6.77   8.000
# 2                 NaN  13.000   7.58  13.000  8.74  13.000  12.74   8.000
# 3                 NaN   9.000   8.81   9.000  8.77   9.000   7.11   8.000
# 4                 NaN  11.000   8.33  11.000  9.26  11.000   7.81   8.000
# 5                 NaN  14.000   9.96  14.000  8.10  14.000   8.84   8.000
# 6                 NaN   6.000   7.24   6.000  6.13   6.000   6.08   8.000
# 7                 NaN   4.000   4.26   4.000  3.10   4.000   5.39  19.000
# 8                 NaN  12.000  10.84  12.000  9.13  12.000   8.15   8.000
# 9                 NaN   7.000   4.82   7.000  7.26   7.000   6.42   8.000
# 10                NaN   5.000   5.68   5.000  4.74   5.000   5.73   8.000
# 11                NaN     NaN    NaN     NaN   NaN     NaN    NaN     NaN
# 12                NaN   9.000   7.50   9.000  7.50   9.000   7.50   9.000
# 13                NaN     NaN    NaN     NaN   NaN     NaN    NaN     NaN
# 14                NaN  10.000   3.75  10.000  3.75  10.000   3.75  10.000
# 15                NaN     NaN    NaN     NaN   NaN     NaN    NaN     NaN
# 16                NaN   0.816    NaN   0.816   NaN   0.816    NaN   0.817
#
#           Unnamed: 9_level_0 Unnamed: 10_level_0
#         Y Unnamed: 9_level_1 Unnamed: 10_level_1
# 0    6.58                NaN                 NaN
# 1    5.76                NaN                 NaN
# 2    7.71                NaN                 NaN
# 3    8.84                NaN                 NaN
# 4    8.47                NaN                 NaN
# 5    7.04                NaN                 NaN
# 6    5.25                NaN                 NaN
# 7   12.50                NaN                 NaN
# 8    5.56                NaN                 NaN
# 9    7.91                NaN                 NaN
# 10   6.89                NaN                 NaN
# 11    NaN                NaN                 NaN
# 12   7.50               Mean                 NaN
# 13    NaN                NaN                 NaN
# 14   3.75           Variance        (Population)
# 15    NaN                NaN                 NaN
# 16    NaN        Correlation           (Pearson)

# %% [markdown]
# ## lets read the file a little better yet by only reading the rows we want

# %%
pd.read_csv("https://raw.githubusercontent.com/fedhere/PUS2020_FBianco/master/data/anscombe.txt", 
            header = [1, 2], nrows = 11, delimiter=' ')
# Out:
#     Anscombe-Data-Set   I         II       III         IV         \
#    Unnamed: 0_level_1   X      Y   X     Y   X      Y   X      Y
# 0                 NaN  10   8.04  10  9.14  10   7.46   8   6.58
# 1                 NaN   8   6.95   8  8.14   8   6.77   8   5.76
# 2                 NaN  13   7.58  13  8.74  13  12.74   8   7.71
# 3                 NaN   9   8.81   9  8.77   9   7.11   8   8.84
# 4                 NaN  11   8.33  11  9.26  11   7.81   8   8.47
# 5                 NaN  14   9.96  14  8.10  14   8.84   8   7.04
# 6                 NaN   6   7.24   6  6.13   6   6.08   8   5.25
# 7                 NaN   4   4.26   4  3.10   4   5.39  19  12.50
# 8                 NaN  12  10.84  12  9.13  12   8.15   8   5.56
# 9                 NaN   7   4.82   7  7.26   7   6.42   8   7.91
# 10                NaN   5   5.68   5  4.74   5   5.73   8   6.89
#
#    Unnamed: 9_level_0 Unnamed: 10_level_0
#    Unnamed: 9_level_1 Unnamed: 10_level_1
# 0                 NaN                 NaN
# 1                 NaN                 NaN
# 2                 NaN                 NaN
# 3                 NaN                 NaN
# 4                 NaN                 NaN
# 5                 NaN                 NaN
# 6                 NaN                 NaN
# 7                 NaN                 NaN
# 8                 NaN                 NaN
# 9                 NaN                 NaN
# 10                NaN                 NaN

# %% [markdown]
# remove useless columns

# %%
# iloc allows me to select only some rows or columns by their position in the DF. 
# the first index passed to iloc controls the rows, the second the columns
# [:] means everything along that axis (here its used to take all rows)
# [1:9] means from the second to the 9th of the rows/or columns
# note! from the second cause pandas is 0-indexed!
pd.read_csv("https://raw.githubusercontent.com/fedhere/PUS2020_FBianco/master/data/anscombe.txt", 
                   header = [1, 2], nrows = 11, delimiter=' ').iloc[:,1:9]
# Out:
#      I         II       III         IV
#      X      Y   X     Y   X      Y   X      Y
# 0   10   8.04  10  9.14  10   7.46   8   6.58
# 1    8   6.95   8  8.14   8   6.77   8   5.76
# 2   13   7.58  13  8.74  13  12.74   8   7.71
# 3    9   8.81   9  8.77   9   7.11   8   8.84
# 4   11   8.33  11  9.26  11   7.81   8   8.47
# 5   14   9.96  14  8.10  14   8.84   8   7.04
# 6    6   7.24   6  6.13   6   6.08   8   5.25
# 7    4   4.26   4  3.10   4   5.39  19  12.50
# 8   12  10.84  12  9.13  12   8.15   8   5.56
# 9    7   4.82   7  7.26   7   6.42   8   7.91
# 10   5   5.68   5  4.74   5   5.73   8   6.89

# %% [markdown]
# ## read in the dataframe into a variable _ansc_

# %%
ansc = pd.read_csv("https://raw.githubusercontent.com/fedhere/PUS2020_FBianco/master/data/anscombe.txt", 
                   header = [1, 2], nrows = 11, delimiter=' ').iloc[:,1:9]
ansc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   (I, X)    11 non-null     int64
#  1   (I, Y)    11 non-null     float64
#  2   (II, X)   11 non-null     int64
#  3   (II, Y)   11 non-null     float64
#  4   (III, X)  11 non-null     int64
#  5   (III, Y)  11 non-null     float64
#  6   (IV, X)   11 non-null     int64
#  7   (IV, Y)   11 non-null     float64
# dtypes: float64(4), int64(4)
# memory usage: 832.0 bytes

# %% [markdown]
# A dataframe is a python object, or class. In this case the class hosts 4 datasets: I,II,III,IV.
# We can think of the dataframe as a python dictionary as well.
#
# If we think of it as a class lets refer to the first dataset identified as I as ```ansc.I```
#
# Otherwise I can refer to it as you would for a dictionary as ```ansc[I]```

# %%
ansc.describe()
# Out:
#                I                    II                   III             \
#                X          Y          X          Y          X          Y
# count  11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean    9.000000   7.500909   9.000000   7.500909   9.000000   7.500000
# std     3.316625   2.031568   3.316625   2.031657   3.316625   2.030424
# min     4.000000   4.260000   4.000000   3.100000   4.000000   5.390000
# 25%     6.500000   6.315000   6.500000   6.695000   6.500000   6.250000
# 50%     9.000000   7.580000   9.000000   8.140000   9.000000   7.110000
# 75%    11.500000   8.570000  11.500000   8.950000  11.500000   7.980000
# max    14.000000  10.840000  14.000000   9.260000  14.000000  12.740000
#
#               IV
#                X          Y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000

# %% [markdown]
# #1 print each of the 4 distributions

# %%
for c in ansc.columns[1::2]:
  print(c)
  print(ansc[c])
# Out:
# ('I', 'Y')
# 0      8.04
# 1      6.95
# 2      7.58
# 3      8.81
# 4      8.33
# 5      9.96
# 6      7.24
# 7      4.26
# 8     10.84
# 9      4.82
# 10     5.68
# Name: (I, Y), dtype: float64
# ('II', 'Y')
# 0     9.14
# 1     8.14
# 2     8.74
# 3     8.77
# 4     9.26
# 5     8.10
# 6     6.13
# 7     3.10
# 8     9.13
# 9     7.26
# 10    4.74
# Name: (II, Y), dtype: float64
# ('III', 'Y')
# 0      7.46
# 1      6.77
# 2     12.74
# 3      7.11
# 4      7.81
# 5      8.84
# 6      6.08
# 7      5.39
# 8      8.15
# 9      6.42
# 10     5.73
# Name: (III, Y), dtype: float64
# ('IV', 'Y')
# 0      6.58
# 1      5.76
# 2      7.71
# 3      8.84
# 4      8.47
# 5      7.04
# 6      5.25
# 7     12.50
# 8      5.56
# 9      7.91
# 10     6.89
# Name: (IV, Y), dtype: float64

# %% [markdown]
# #2 extract the mean from each distribution
# #3 extract the standard deviation from each distribution

# %%
print("Distribution Means:               " + 
      "{0:.2f}, {1:.2f}, {2:.2f}, {3:.2f}"\
    .format(ansc["I"]["Y"].mean(), ansc["II"]["Y"].mean(), 
            ansc["III"]["Y"].mean(), ansc["IV"]["Y"].mean()))
print("Distribution Standard Deviations: " + 
      "{0:.2f}, {1:.2f}, {2:.2f}, {3:.2f}"\
    .format(ansc["I"]["Y"].std(), ansc["II"]["Y"].std(), 
            ansc["III"]["Y"].std(), ansc["IV"]["Y"].std()))
# Out:
# Distribution Means:               7.50, 7.50, 7.50, 7.50
# Distribution Standard Deviations: 2.03, 2.03, 2.03, 2.03

# %% [markdown]
# #4 plot the mean and standard deviaion as 4 datapoints with errorbars into the same plot

# %%
fig = pl.figure(figsize=(10, 5))
ax = [0] * 2

ax[0] = fig.add_subplot(121)
ax[1] = fig.add_subplot(122)
colors=['DarkMagenta', 'MediumTurquoise', 'tomato', 'gray']
for i in range(2):
    ax[i].set_xticks([],[])

#means plot
#this is the essential plotting command
ax[0].scatter(range(4), [ansc["I"]["Y"].mean(), ansc["II"]["Y"].mean(), 
            ansc["III"]["Y"].mean(), ansc["IV"]["Y"].mean()],
            s = 100, c = colors)
#additional stuff to prettify the plot
#label
ax[0].text(0.5, 0.75, 'mean', horizontalalignment = "center", 
           transform = ax[0].transAxes, fontsize = 19)
#y limits
ax[0].set_ylim(ansc.I.Y.mean()-0.01, ansc.I.Y.mean()+0.01)
ax[0].set_ylabel("Ascombie's values")
#standard deviations plot
ax[1].scatter(range(4), [ansc.I.Y.std(), ansc.II.Y.std(), ansc.III.Y.std(), ansc.IV.Y.std()], 
              s = 100, c = colors)
#label
ax[1].text(0.5, 0.75, 'standard deviation', horizontalalignment = "center", 
           transform = ax[1].transAxes, fontsize = 19)
#y limits
ax[1].set_ylim(ansc.I.Y.std()-0.01, ansc.I.Y.std()+0.01);
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.

# %%
#error bar plot : visualizes both mean and standard deviation
ax = pl.figure(figsize=(10, 5)).add_subplot(111) 

colors=['DarkMagenta', 'MediumTurquoise', 'tomato', 'gray']
ax.set_xticks([],[])

ax.errorbar(range(4), [ansc["I"]["Y"].mean(), ansc["II"]["Y"].mean(), 
            ansc["III"]["Y"].mean(), ansc["IV"]["Y"].mean()],
            yerr = [ansc["I"]["Y"].std(), ansc["II"]["Y"].std(), 
            ansc["III"]["Y"].std(), ansc["IV"]["Y"].std()],
            label= ['mean I', 'mean II', 'mean II', 'mean VI'], alpha=0.5, ecolor = colors, 
            fmt='o');

plt.ylabel("Ascombie's values")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   """
# Text(0, 0.5, "Ascombie's values")

# %% [markdown]
# # cool! they are identical! identical mean, identical standard deviation
# hence we are looking at the same distribution i guess.
# let's fit a line to it

# %% [markdown]
# #7 boxplot: plot a boxplot for each distribution
#
# well... not so identical after all. The boxplot shows median, interquartile range, full range, and outliers

# %%
pl.boxplot([ansc["I"]["Y"], ansc["II"]["Y"], 
            ansc["III"]["Y"], ansc["IV"]["Y"]]);

pl.xticks([]);
pl.ylabel("Ascombie values");

# %% [markdown]
# #5 fit a line to each of the 4 distributions
#
# #6 plot each of the 4 distributions as a scatter plot (y vs x) and if you fit a line to the distribution also plot the line fit
#
# #7 plot the residuals of the line model for each distribution

# %%
import statsmodels.api as sm
fig = pl.figure(figsize=(20,10))
models = []
for i,a in enumerate([ansc.I, ansc.II, ansc.III, ansc.IV]):
  models.append(sm.OLS(exog=a.X, endog=a.Y).fit())
  ax = fig.add_subplot(2,4,i+1)
  ax.plot(a.X, a.Y, 'o')
  ax.plot(a.X, models[i].predict())
  ax = fig.add_subplot(2,4,i+5)  
  ax.plot(a.X, a.Y - models[i].predict(), 'o')
  ax.plot([a.X.values.min(), a.X.values.max()], [0,0], '-')
