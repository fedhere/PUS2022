# %% [markdown]
# <a href="https://colab.research.google.com/github/fedhere/PUS2022_FBianco/blob/main/classdemo/titanicdemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
#cd /content/drive/My Drive

# %%
cd /content/gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
ls
# Out:
# '000_0027_Emille_Ishida-e1535476162261 (1).png'
#  00101.mov
#  00102.mov
#  00103.mov
#  00104.mov
#  10.5334_dsj-2015-011_T1.csv
#  10.5334_dsj-2015-011_T1.gsheet
# '109197-25 Non-Final OA.zip'
#  11bov.pdf
# '11fe summary.gdoc'
#  11img-179017.png
# '1 2017 Proposal Award Information Form & Guidelines.pdf'
#  2003VS2.png
#  2013Jul15_obslog_0327.log
#  2018-07-17_SC.pdf
# '2018 Capstone assignments FINAL.XLSX'
# '2018 Capstone assignments - worksheets.xlsx'
# '2018 Capstone assignments - worksheets.xlsx.gsheet'
#  2021-04-22T2051_Grades-21S-PHYS207-013.csv
# '2021-23 - DrlicaWager_Enabling_Science_Proposal_2021.gdoc'
# '2021-23 - DrlicaWager_Enabling_Science_Proposal_2021.pdf'
# '2021 SSSC Working Group Leads Nomination Form (Responses).gsheet'
#  20220510_154017.jpg
#  2022-06-01T0052_Grades-22S-PHYS667-010.csv
#  2022-06-01T0052_Grades-22S-PHYS667-010.gsheet
# '21A00327_OAD Grant Agreement_Bianco.docx'
# '2 2017 Final Report and Financial Attestation Forms.pdf'
# '3 2017 Financial Report Template.xlsx'
# '3rdworkshop signup.gsheet'
# '4 Form W-9.pdf'
#  5.25.pdf
#  8:00.gdoc
#  A1DBA84B-27E0-4B23-A409-135AA52FB3FD.png
# 'AAS12948 referee report.gdoc'
# 'aas 2011 austin costs.gsheet'
# 'AAS2020 LSST Science Collaborations .gslides'
# 'AAS 237 Rubin MMT TDA.gslides'
# 'AAS announcement of focus issue.gdoc'
# 'AAS check list.gsheet'
# 'AAS - EDU cheatsheet.pdf'
# 'aas membership.gsheet'
# 'AAS Poster Quaoar.jpg'
#  abdulqaATudel.edu.png
# 'Abundance_Maryam_29_Aug13 (1).pro.gdoc'
#  Abundance_Maryam_29_Aug13.pro
#  Abundance_Maryam_29_Aug13.pro.gdoc
# 'Academic Review committee POTU.gdoc'
# 'A  Cadence  to  Reduce  Aliasing  in  LSST Bell.gdoc'
# 'Accelnet 2020 notes.gdoc'
#  AceroCuellarEnablingScience2021.gdoc
# 'AC NSF ID -000747680 -Bianco Federica.docx'
#  Acquaviva.gdoc
# 'added coauthors.gsheet'
# 'ADHD?.gdoc'
# 'A Diversity and Inclusion Committee of the Department of Physics and Astronomy at the University of Delaware.gdoc'
# 'A Fairness Framework for Artificial Intelligence.gdoc'
#  AGNlogo.gdraw
# 'A  Higher  Cadence  Subsurvey  Located  in  the Galactic  Plane Lund.gdoc'
#  alienmovies.gsheet
#  alienmovies.tsv
#  all_ones_benchmark.zip
# 'All submitted Applications_ Basic data as of 2020 02 03-2.gsheet'
# 'All submitted Applications_ Basic data as of 2020 02 03-2.xlsx'
#  all_zeros_benchmark.zip
# 'amazing women.gdoc'
# 'Amin Boukari UD DSI Symposium Presentation.mp4'
# 'Ana version (just one page).gdoc'
# 'A new spreadsheet.gsheet'
# 'An Extreme Rolling Cadence (for TDEs) Gezari.gdoc'
# 'Announcing LSST@Europe4.gdoc'
# 'anonymized decolonizing physics class activity.gsheet'
# 'Antiracism workshop.gsheet'
# 'Antonio Kodsy qualifier.gdoc'
#  AphasiaActivityNamingandWriting-1.zip
#  apiks/
#  APIreadingJson.ipynb
# 'API TEAM-UP REPORT: DPA SELF-ASSESSMENT.gform'
# 'API TEAM-UP REPORT: DPA SELF-ASSESSMENT (Responses).gsheet'
# 'ApJS Focus Issue authors.gsheet'
#  __appdata__/
# 'application season 2015.gsheet'
# 'application season 2015.xlsx'
#  APR_proposed_reviewers.pdf
# 'APS P4PG.gsheet'
# 'Are we alone? Searching for Intelligent Life with LSST.gdoc'
# 'armin Statement of Work NSFAAG2019 LE.gdoc'
# 'ARPAe docs'/
#  arshiyakATudel.edu.png
#  AS4_TDA_20160211.docx
#  AS4_TDA_Nov2015_20160119notes_ecb.docx.gdoc
# 'Assessment of the impact of an LSST ODF from the Science Collaborations (1).pdf'
# 'Assessment of the impact of an LSST ODF from the Science Collaborations.pdf'
# 'astro 101 2013 grades.gsheet'
#  Astro2020SCsF1.gdraw
#  Atimeexchangemodel-thoughtsandscribblings.docx
#  August/
#  authorAffiliations.csv
#  authorAffiliations.gsheet
#  AVerma-biosketch-2020.pdf
#  baseline_v2.0_10yrs.mp4
#  baselineV3.mp4
#  BaurJulienFBB.gdoc
#  bdastro.pdf
#  behavpp.gslides
#  berlusconi_eng.doc.gdoc
# 'BEST HACK (1).pdf'
# "beth's recommendation to hiring firm.gdoc"
# 'bg 2.png'
#  bg.jpg
# 'BIA02-01 Modified Provisional Application - with GA_s changes-c SEK.docx'
# 'BIA02-01 Modified Provisional Application - with GA_s changes-c SEK.gdoc'
#  Bianco--1-26-2015.doc
# 'bianco+2014 answers.gdoc'
# 'Bianco 2019-20_revised_pdf.ps'
#  biancoAAG2020proposal.pdf
# 'BiancoAAS233TownHallPPT 3 (1).key'
# 'BiancoAAS233TownHallPPT 3.key'
# 'Bianco candidate_updates_1.docx'
# 'Bianco FacultyAppraisal_2021.pdf'
#  Bianco_Federica-2018-03.jpg
# 'Bianco GRU 2019.gdoc'
# 'Bianco-headshot (1).jpg'
#  Bianco-headshot.jpg
# 'bianco_jsm2020 (1).pdf'
#  bianco_jsm2020.pdf
#  BiancoLSST_CTA032020.pdf
#  BiancoNAM22RubinIntro.pdf
# 'BiancoNSFAAG2019 Letter of collaboration.gdoc'
# 'Bianco NSF AAG Budget - 2020 (1).gsheet'
# 'Bianco NSF AAG Budget - 2020 (1).xlsx'
# 'Bianco NSF AAG Budget Justification.docx'
# 'Bianco NSF AAG Budget Justification.gdoc'
# 'Bianco NSF AAG Budget v1 (1).gsheet'
# 'Bianco NSF AAG Budget v1 (1).xlsx'
# 'Bianco NSF AAG Budget v1.gsheet'
# 'Bianco NSF AAG Budget v1.xlsx'
#  Bianco_NSF_budget_draft.gsheet
# 'Bianco NSF Career2020Budget v1 (1).gsheet'
# 'Bianco NSF Career2020Budget v1 (1).xlsx'
# 'Bianco NSF Career2020Budget v1.gsheet'
# 'Bianco NSF Career2020Budget v1.xlsx'
# 'Bianco NSF Career 2021 Budget GS (1).xlsx'
# 'Bianco NSF Career 2021 Budget GS.xlsx'
# 'Bianco-nsf_current_pending062020 (1).docx'
# 'Bianco-nsf_current_pending062020 (1).gdoc'
# 'Bianco-nsf_current_pending062020 (2).docx'
# 'Bianco-nsf_current_pending062020 (3).docx'
#  Bianco-nsf_current_pending062020.docx
#  Bianco-nsf_current_pending062020.gdoc
#  Bianco.pdf
# 'Bianco P&T notice.gdoc'
#  biancorubinlat.pptx
#  bianco_S1_EWASS2019_LSST.pdf
# 'Bianco_SC_F2F2018 (1).pdf'
#  Bianco_SC_F2F2018.pdf
#  Bianco_SPHERExLSST2.key
#  Bianco_TAMU2020.pdf
# 'Bianco_to_Reviewers - Dossier for promotion to the rank of Associate Professor (1).pdf'
# 'Bianco_to_Reviewers - Dossier for promotion to the rank of Associate Professor.pdf'
#  Bianco_Transients2020_1.pdf
# 'Bianco UDel Phsyica&Astronomy   DSI  postdoc PDR.gdoc'
#  bidenCovidPanel/
# 'Biden School Fall 2020_Hybrid Schedule_Final.gsheet'
# 'Biden School Fall 2020_Hybrid Schedule_Final.xlsx'
# 'Bio Bianco.gdoc'
# 'Bio Bianco.pdf'
#  biosketch.pdf
# 'Blazars  (and  FRBs)  with  LSST Raiteri.gdoc'
#  blurb.gdoc
#  bogcl/
#  Book3.xlsx
#  bookmarks_11_26_17.html
# 'BOOM! feedback form.gform'
#  bootplot4.py
#  Boukari-Budget-UDel-Subaward-NSF_DataScienceTraining.xlsx
# 'Boxing Answers .gdoc'
#  box_whisker_pca.png
# 'briefing on ODF - Steve Kahn - SC chairs.gdoc'
# 'Budget - Bianco - Drexel-NSF HRDv2gtr v3.xlsx'
# 'Budget - Bianco - Drexel-NSF HRD.xlsx'
# 'Budget - Bianco -NSF 21-523 reduced (1).xlsx'
# 'Budget - Bianco -NSF 21-523 reduced.xlsx'
# 'Budget - Bianco -NSF 21-523 v1.xlsx'
# 'Budget - Bianco - UC Subaward.xlsx'
# 'Budget Justification Bianco ADAP.gdoc'
# 'budget-justification - Bianco.docx'
# 'Budget Justification.docx'
#  Budget_justification_NSF_UWM_Bianco.docx
# 'Budget  - NIH ACCEL.xlsx'
# 'Budget  - NSF 19-501 - Bianco.xlsx'
#  building-comprehensive-complete.zip
#  bulkCompile_2020125.pdf
#  CAA_LSSTSCs.gslides
#  CAA_LSSTSCs.key
#  CAA_LSSTSCs.pdf
# 'Call for Participation V2.1.docx'
# 'Call for Participation V2.1.gdoc'
# 'Camping graucery list.gdoc'
# 'candidacy exam'/
#  candidate_updates_1.docx
# 'career2020y12 (10).png'
# 'career2020y12 (1).png'
# 'career2020y12 (2).png'
# 'career2020y12 (3).png'
# 'career2020y12 (4).png'
# 'career2020y12 (5).png'
# 'career2020y12 (6).png'
# 'career2020y12 (7).png'
# 'career2020y12 (8).png'
# 'career2020y12 (9).png'
#  career2020y12.drawio
#  career2020y12.png
# 'career2020y234 (1).png'
# 'career2020y234 (2).png'
# 'career2020y234 (3).png'
# 'career2020y234 (4).png'
# 'career2020y234 (5).png'
# 'career2020y234 (6).png'
#  career2020y234.drawio
#  career2020y234.png
#  carousel_image_fb084d49f0320057c720_DSC_0777.JPG
# 'Carreer Grant Proposal 01 03 2019.gdoc'
#  cartogramcovid0323.mp4
#  CASRecruitmentPosting_Astroparticle2022_draft14Sep2021.docx
# 'Catalyst fellowship mentors.gsheet'
# 'Catalyst mentors headshot (File responses)'/
# 'Catalyst mentors headshot.gform'
# 'Catalyst mentors headshot (Responses).gsheet'
# 'CBCB Academic Advisor_2022_07.docx'
# 'CDEI Committee recommendations to the Faculty Search committees - 2022-2023.gdoc'
# 'CEC planning chat - Fed and Phil - 12 19.gdoc'
#  celebrateak.mov
#  censusapi.txt
# 'census tracts geoid hint.gdoc'
#  central_pixel_benchmark.zip
#  CfA.SNIbc.BIGINFO.list.gsheet
#  CfA.SNIbc.BIGINFO.list.txt
#  CfA.SNIbc.BIGINFO_notused.gsheet
#  Chabad.docx
#  Chabad.gdoc
# 'Changes to PASP-100746 .gdoc'
# 'CHIME 101.gdoc'
#  chordd.mov
# 'Chotard+ 2011.gslides'
# 'Citations for prior NSF support: All.gdoc'
#  citibikes/
#  classes/
# 'Class notes.gdoc'
# 'Climate, Diversity, Equity, and Inclusion  at the  Department of  Physic and Astronomy.gslides'
#  Closing_Remarks_440_to_5_Incomplete.pptx
#  ClosingTheLoop_NSFInstitute_MeetingNotes.gdoc
#  coa_Bianco.gsheet
#  coa_Bianco.xlsx
#  co_fed.gdoc
# 'Colab Notebooks'/
# 'Colloquium Dr. Bianco Meeting Itinerary.docx'
# 'colloquium suggestions and speakers nominations.gform'
# 'colloquium suggestions and speakers nominations (Responses).gsheet'
#  commandation_letter.gdoc
#  commandation_letter.pdf
# 'comments on the Rubin SCs Census.gdoc'
# 'Commissioning liaisons chat 1.gdoc'
# 'CommitteeMbrship 2021-2022.xlsx'
# 'Committees guidelines from Executive Board Handbook_Final_R2_21Mar2018.pdf'
#  comp_Fe_old_new.csv
#  comp_Fe_old_new.gsheet
# 'Concept Page.docx'
# 'Concept Page.gdoc'
# 'Concept Page_NOT_GM_20_025.docx'
# 'Concept Page_Personnel (1).docx'
# 'Concept Page_Personnel (1).gdoc'
# 'Concept Page_Personnel.docx'
# 'Concept Page_Personnel.gdoc'
#  congiunione_tx.jpg
# 'Continuous  Cadence  Acquisition  of  the  LSSTDeep  Drilling  Fields Bell.gdoc'
# 'Copy of 2020 LSST DESC Census & Effort Tracking for TVS.gform'
# 'Copy of 6. Aggregation task.gdoc'
# 'Copy of AAS 237 Rubin Open House presentation.gslides'
# 'Copy of all_music_gear.gsheet'
# 'Copy of BaurJulienFBB.gdoc'
# 'Copy of BIA02-01 Modified Provisional Application - with GA_s changes-c SEK - sek.gdoc'
# 'Copy of Carreer Grant Proposal 01 03 2019.gdoc'
# 'Copy of CfA.SNIbc.BIGINFO.list.gsheet'
# 'Copy of Consulting Billing Rate Floor Calculator.gsheet'
# 'Copy of Dearholmes Customizable Welcome Letter.gdoc'
# 'Copy of DPADEI4facultymeeting091220.gslides'
# 'Copy of Federica Bianco II 2019 Talk prep .gdoc'
# 'Copy of intro to  SSSC newsletter.gdoc'
# 'Copy of Jordan Harrod_Short Bio.gdoc'
# 'Copy of LSST2019: LSST SCIENCE.gslides'
# 'Copy of LSST@Europe4 Registration (1).gform'
# 'Copy of LSST@Europe4 Registration.gform'
# 'Copy of LSST@Europe4 Registration (Risposte).gsheet'
# 'Copy of MATCH (1).gsheet'
# 'Copy of MATCH (2).gsheet'
# 'Copy of MATCH (3).gsheet'
# 'Copy of MATCH (4).gsheet'
# 'Copy of MATCH (5).gsheet'
# 'Copy of MATCH (6).gsheet'
# 'Copy of MATCH.gsheet'
# 'Copy of Mitigations working group plan.gdoc'
# 'Copy of MMA-TDA-Writers-workshop.gslides'
# 'Copy of NSF DSC CoI contribution form.gform'
# 'Copy of Occultation Key Project .gdoc'
# 'Copy of Presentation Template GoogleSlides.gslides'
# 'Copy of Proposal_APSInnovFund_2021 (1).gdoc'
# 'Copy of Proposal_APSInnovFund_2021.gdoc'
# 'Copy of QUERY (1).gsheet'
# 'Copy of QUERY.gsheet'
# 'Copy of Rank Example.gsheet'
# 'Copy of resume.gdoc'
# 'Copy of Rubin Observatory LSST In-Kind Contributions 2019 - CEC Worksheet (1).gsheet'
# 'Copy of Rubin Observatory LSST In-Kind Contributions 2019 - CEC Worksheet (2).gsheet'
# 'Copy of Rubin Observatory LSST In-Kind Contributions 2019 - CEC Worksheet.gsheet'
# 'Copy of Rubin Project and Community Workshop anti-racism workshop interest form..gform'
# 'Copy of Rubin Project and Community Workshop anti-racism workshop interest form. (Responses).gsheet'
# 'Copy of Survey Strategy Session III.gslides'
# 'Copy of TOM Proposals Ranking.gsheet'
# 'Copy of TVS Catalyst fellowship mentors.gform'
# 'Copy of Vision for a Data Science curriculum for Public Service.gdoc'
#  coronavirusCartogram.gif
#  coronavirusCartogram.mov
#  COVID-19-contagion.gif
#  COVID-19-countireswdeath.gif
# 'COVID-19-deaths (1).gif'
#  COVID-19-deaths.gif
# 'COVID IAU proposal.gdoc'
# 'C&P.docx'
# 'C&P.gdoc'
#  CSAC.gdoc
#  CSIAgenda4.12.17.pdf
#  CUSP/
#  CUSPstudents_netIDGithub.gsheet
#  cv19/
#  d11_dom.gsheet
#  dads/
#  DAMADSC2022_poster.key
#  DarkUniverseNoSN.mp4
#  DarkUniverseNoSN_slow.mov
#  dashboard-export-05-15-pm-2022-04-25.csv
#  data/
#  Data/
#  Data_access_example.ipynb
# 'Data and project sharing for DSC.gform'
# 'Data and project sharing for DSC (Responses).gsheet'
# 'data cc'/
#  data_note.pdf.zip
# 'Data Science and Cyber Research Interests and Skills - bianco'
# 'Data Science and Cyber Research Interests and Skills - bianco.gdoc'
# 'Data Science Course Matrix S20 v1.xlsx'
# 'DDP-WG Charter.gdoc'
# 'DDP-WG Charter.pdf'
#  DDT_HD187091.gdoc
# 'Dear Editors of Astronomy&Computing,.gdoc'
# 'deca betha.gdoc'
# 'December 6 LSST SC chairs call.gdoc'
# 'December 7th CUSP HackDay.gdoc'
#  DE_COVID_2020_04_05.gsheet
#  DE_COVID_2020_04_05.xlsx
# 'DEI session Ameerah meeting .gdoc'
# 'DEI session at PCW 2020 strawperson plan.gdoc'
# 'DEI session PCW 2020.gdoc'
# 'DE legislative reform'/
#  descmembers.gsheet
#  descsticker.gdraw
# 'DESC-to-SCOC-20220610 (2).pdf'
# 'dharmacorner_DE (6).png'
#  DiversityTimeSeries.xlsx
#  dobler_dectr20_research_strategy.docx
#  dobler_hadive.docx
# 'Dobler_Research_Assoc (1).docx'
# 'Dobler_Research_Assoc (1).gdoc'
#  Dobler_Research_Assoc.docx
#  Dobler_Research_Assoc.gdoc
#  dobler_scc19_budget_example.xls
#  dobler_sts19_coa.xlsx
# 'Done for house.gsheet'
# 'DOSSIER LYMAN AUG 29 (2).pdf'
#  DossierPnTBianco.pdf
# 'DPA 2020 colloquium questions.gform'
# 'DPA 2020 colloquium students sign up.gform'
# 'DPA Academic Programs and Climate Survey_Students only-Feb 14-2022.xlsx'
# 'DPA CDEI committee charter update.gslides'
# 'DPA Climate Survey_Faculty and Staff-Feb 14-2022.xlsx'
#  DPADEI4facultymeeting091220.gslides
#  DPADEI4facultymeeting091220.key
# 'DPA TEAM-UP workshop application.gdoc'
# 'draft (1).gdoc'
#  draft.gdoc
#  driserATudel.edu.png
#  DSC_0089.AVI
# 'DSDS quiz 14.gdoc'
# 'DSI Postdoc and Grad-student (self) nomination.gform'
# 'DSI Postdoc and Grad-student (self) nomination (Responses).gsheet'
# 'DSI stickers.gdoc'
#  dsi_symposium_2019_program_draft_061919.docx
# 'DSI symposium 2021 exit survey.gform'
# 'DSI symposium 2021 poster voting portal.gform'
# 'DSI symposium  Applications stats.gdoc'
# 'DSPP curriculum logic model (1).jpg'
# 'DSPP curriculum logic model (1).png'
# 'DSPP curriculum logic model (2).jpg'
# 'DSPP curriculum logic model (2).png'
# 'DSPP curriculum logic model (3).jpg'
# 'DSPP curriculum logic model.drawio'
# 'DSPP curriculum logic model_final2.png'
# 'DSPP curriculum logic model_final.png'
# 'DSPP curriculum logic model.jpg'
# 'DSPP curriculum logic model.png'
# 'DSPP curriculum logic model.svg'
# 'DSPS2019 Extra Credit Project Proposal.gdoc'
# 'DSPS 2019 quiz 6 - Google Docs-1.pdf'
#  dsps2021/
# 'DSPS 2021 Quiz 10.gform'
# 'DSPS 2021 Quiz 18.gform'
# 'DSPS 2021 quiz 4.gform'
# 'DSPS 2021 quiz 7.gform'
# 'DSPS Extra Credit Project Template.gdoc'
# 'DSPS final form.gform'
# 'DSPS quiz 11 (File responses)'/
# 'DSPS quiz 11.gform'
# 'DSPS quiz 11 (Responses).gsheet'
# 'DSPS quiz 13.gform'
# 'DSPS quiz 16 (File responses)'/
# 'DSPS quiz 16.gform'
# 'DSPS quiz 17.gform'
# 'DSPS syllabys - in intaliano.gdoc'
#  dstep20_flyer.gdoc
#  dstep20_flyer.pdf
# 'DTU17 classification data challenge.gdoc'
# "Ed's version Student and Postdoctoral Fellow Climate Survey in the Natural Sciences and Mathematics.gdoc"
# 'Ejecta mass Phot Analysis paper outline 2015-16.gdoc'
# 'Electromagnetic Follow Up of MMA triggers.gdoc'
# 'email about teaching PHYS133.gdoc'
# 'Email message accompanying the statement of values.gdoc'
# 'Endorsement of LSST Corporation Activities by the LSST Science Collaborations.gdoc'
# 'eq 9.gdoc'
#  Erba_change_dissertation_committee.pdf
#  ESB_119.75_camera4_50ms_1999_1706.GIF
#  eta07_eta09.gsheet
# 'eta car echoes meeting 04 23.gdoc'
# ' eta car echoes  TARGET LIST.gdoc'
# 'eta DECAM coordinates.gsheet'
# 'eta light echoes in colors.gsheet'
#  etaspec14A.fed.tex
#  ETFs/
#  ETHAI.gdoc
#  EthnictyCOVID-19Dataset.csv
# 'example name tag.gslides'
# 'example name tag LSST@Eu4.gslides'
# 'Exit survey : TVS-SMWLV meeting and hackathon 2019.gform'
# 'Exit survey : TVS-SMWLV meeting and hackathon 2019 (Responses).gsheet'
# 'Explosive  Physics  and  Fast  Transients  White  PaperCadence Bianco.gdoc'
#  ezgif-6-68339951da40.mp4
#  ezgif-6-bf303b12c5b5.mp4
#  ezgif-6-e6a74c18b304.mp4
# 'Fact Check_Federica Bianco_v2 (1).gdoc'
# 'Fact Check_Federica Bianco_v2.docx'
# 'Fact Check_Federica Bianco_v2.gdoc'
# 'Faculty and Staff Women in Physics.xlsx'
# 'FASTLab Annual Self Assessment.gform'
# 'FASTLab Annual Self Assessment (Responses).gsheet'
# 'Fastlab Boom Talks Feedback.gdoc'
#  FASTlab.gsheet
# 'FASTlab resources curation sign up list.gsheet'
# 'Fast Transients cadence proposal call 11 12.gdoc'
# 'Fast Transients.gslides'
#  FBB_collab_letter.pdf
# 'F.B.Bianso SC Coordinator worksheet 2018-2019.gsheet'
# 'F.B.Bianso SC Coordinator worksheet 2019-2020.gsheet'
# 'F.B.Bianso SC Coordinator worksheet 2019-2020.xlsx'
# 'F.B.Bianso SC Coordinator worksheet.gsheet'
#  fbb_K2_biosketch.gdoc
#  fbbresume.gdoc
# 'FBB review of RESULT OF THE PHOTOMETRIC LSST ASTRONOMICAL TIME SERIES CLASSIFICATION CHALLENGE Hlozek et al.gdoc'
# 'FBB SC Coordinator 2019 INVOICE.gdoc'
# 'FBB SC Coordinator 2021 INVOICE.gdoc'
#  FBBshortCV.gdoc
#  fbbTedTalk_take1.mov
#  fbbUDAlumni2019.key
#  fbb_UD.gdoc
# 'FBianco - Mobility|Cosmology.gdoc'
#  fb_teaching.pdf
#  FD-II.gdoc
# 'FDSfE 2022 Quiz solutions.gdoc'
# 'FDSfE Fall 2022 Quiz 4.gform'
# 'FDSfE Fall 2022 Quiz 5.gform'
# 'FDSfE quiz 2.gform'
#  Fed/
#  Fed2/
# 'Fed and Kim.mp4'
# 'federica bianco - computer needs.gdoc'
# 'federica bianco computer needs.gsheet'
# 'FedericaBianco[FinalJPEGs]-257.jpg'
# 'FedericaBianco[FinalJPEGs]-270.jpg'
# 'federica bianco -- funding request contingent upon better understanding of USF support system.gsheet'
# 'Federica Bianco II 2019 Talk prep  saved  .gdoc'
# 'Federica Bianco_PR Guide_TED2019 Fellows.gdoc'
# 'Federica Bianco_reviewed_sarangof.docx'
# ' Federica Job Applications 2012 for tim.gsheet'
# 'Federica Job Applications 2012.gsheet'
# 'fed job apps 2014-5 Andy.gsheet'
# 'fed job apps 2014-5 - Charles.gsheet'
# 'fed job apps 2014-5.gsheet'
# 'fed job apps 2014-5 HOGG.gsheet'
# 'Fed NIH Biosketch.docx'
# 'Fed NIH Biosketch.gdoc'
# 'Female Undergrads in Physics for 2193.xlsx'
# 'Fermi School 2020-NASA Inv.pdf'
#  fevel.gsheet
# 'fig5 .gdraw'
#  fights/
#  filament/
#  File_000.jpeg
#  File_000.mov
# 'final 2013.gdoc'
# 'Flarubin References.gdoc'
#  floor.gsheet
# 'fly-america-waiver-checklist - Bianco.docx'
# 'foundations 2.gsheet'
# 'foundations 3.gsheet'
#  Fragment.tex.gdoc
#  fridge.gsheet
#  FTN_20110623_Charon_boxcar.ps
#  FTN_20110623_Pluto_halflight.ps
#  fundedProposals.gdoc
# "gabriella's thesis - copy.gdoc"
# 'Gaia-LSST Synergy and Constraints to Pulsation Theory using LSST: Observations of variable stars in Local Group stellar systems.gdoc'
# 'Galaxies plenary.gslides'
#  GalSClogo.gdraw
# 'GBS Committee Report and Notes.gdoc'
# 'GCC Fellowship Committee Survey Responses 10-7-20.gsheet'
# 'GCC Fellowship Committee Survey Responses 10-7-20.xlsx'
# 'GCC Fellowship Meeting 6-29.docx'
# 'GCC Fellowship Meeting 6-29.gdoc'
#  gender_submission.csv
#  GenovaNightLights.mov
# 'genova quick tour.gmap'
#  GeospatialPixelLevelModel.gslides
# 'GETTING AND PROCESSING DECAM DATA.gdoc'
# "Gleason's Gym.gmap"
#  GMT2014.pdf
#  GMT20221103-191833_Recording_2318x1150.mp4
#  GMT20221103-191833_Recording.m4a
#  GoogleAIXiaolong/
# 'Google Buzz'/
# 'Google Keep Document.gdoc'
# 'Grad College Fellowships (1).docx'
# 'Grad College Fellowships.docx'
# 'Grad College Fellowships.gdoc'
#  graded.csv
# 'Grad Scholar Award 071620 edits.docx'
# 'Grad Scholar Award 071620 edits.gdoc'
# 'GSM Dissertation Proposal_Methods_Aim 1.docx'
#  Guide_to_Chambliss_Judging_final_Dec_2014.pdf
#  guoxinATudel.edu.png
#  GW150914_4_NR_waveform.txt
#  GW.jpg
#  h6moving.gdoc
# 'hacathon pitch slides'/
# 'hackathon flowchart.gdraw'
# 'Hackathon howto.gdoc'
#  HalfSemestergradesMorning.png
#  haobaizATudel.edu.png
# 'Hi Bob and Phil (and Rachel in CC),.gdoc'
#  HiggsBosonCompetition_AMSMetric_rev1.py
# 'HINTS DSPS final 2019.gdoc'
# 'Hogg Bianco - NASA K2 Budget (1).xls'
# 'Hogg Bianco - NASA K2 Budget.xls'
#  HOMLPython.gdoc
#  HonorariosFederica.docx
#  house.gsheet
# 'house renovation.gsheet'
# 'How does an unconference work.gdoc'
#  how_to_do_nonlinearWCS
# 'how to share google docs.gdoc'
#  HS_DataScience2019Scores.gsheet
#  HS_DataScience2019Scores.xlsx
# 'H-S Press Release 8_5_2021.pdf'
#  HTIdrawings.png
#  Hubbleconstant.gdoc
#  HW5_s14.pdf
# 'Hypertemporal visible imaging of an urban lightscape can reveal the phase of the electrical grid granular to individual housing units.gdoc'
#  hzhangATudel.edu.png
#  image.jpg
#  images_training_rev1/
#  IMBREPOSTobacco2019.gdoc
#  imdb-dataset-of-top-1000-movies-and-tv-shows.zip
#  IMG_0008.MOV
#  IMG_0117.JPG
#  IMG_0118.JPG
#  IMG_0120.JPG
#  IMG_0229.TRIM.MOV
#  IMG_0316.JPG
#  IMG_0339.MOV
#  IMG_0780.MOV
#  IMG_0782.MOV
#  IMG_0783.MOV
#  IMG_0867.JPG
#  IMG_0904.JPG
#  IMG-1661.JPG
#  IMG_1716.JPG
#  IMG_1717.JPG
#  IMG_1718.JPG
#  IMG_1719.JPG
#  IMG_1720.JPG
#  IMG_1721.JPG
#  IMG_1722.JPG
#  IMG_1723.JPG
#  IMG_1810.JPG
#  IMG_1811.JPG
#  IMG_1812.JPG
#  IMG_1813.JPG
#  IMG_1814.JPG
#  IMG_1815.JPG
#  IMG_1816.JPG
#  IMG_1817.JPG
#  IMG_1818.JPG
#  IMG_1819.JPG
#  IMG_1890.JPG
#  IMG_20140218_180333.jpg
#  IMG_20140220_192020.jpg
#  IMG_20140221_091155.jpg
#  IMG_20140222_151214.jpg
#  IMG_20140222_151307.jpg
#  IMG_20140222_151309.jpg
#  IMG_20140222_151310.jpg
#  IMG_20140222_151316.jpg
#  IMG_20140222_151416.jpg
#  IMG_20140222_151424.jpg
#  IMG_20140222_171540.jpg
#  IMG_20140222_171541.jpg
#  IMG_20140222_171543.jpg
#  IMG_20140222_171549.jpg
#  IMG_20140222_171556.jpg
#  IMG_20140222_171617.jpg
#  IMG_20140222_172001.jpg
#  IMG_20140222_172142.jpg
#  IMG_20140222_172145.jpg
#  IMG_20140222_172202.jpg
#  IMG_20140222_172207.jpg
#  IMG_20140222_172211.jpg
#  IMG_20140222_173641.jpg
#  IMG_20140222_173916.jpg
#  IMG_20140222_173935.jpg
#  IMG_20140222_173948.jpg
#  IMG_20140222_173957.jpg
#  IMG_20140222_214808.jpg
#  IMG_20140222_214814.jpg
#  IMG_20140222_214817.jpg
#  IMG_20140223_081628.jpg
#  IMG_20140223_081633.jpg
#  IMG_20140223_140059.jpg
#  IMG_20140223_143529.jpg
# 'IMG_20140223_145213 (1).jpg'
#  IMG_20140223_145213.jpg
# 'IMG_20190810_081044_exported_stabilized_215728302638536747 (1).mp4'
#  IMG_20190810_081044_exported_stabilized_215728302638536747.mp4
#  IMG_20200418_233004.dng
#  IMG_2177.jpg
#  IMG_2178.jpg
#  IMG_2182.jpg
#  IMG_2192-1.jpg
#  IMG_2192.jpg
#  IMG_2909.HEIC
#  IMG_3406.MOV
#  IMG_6180.MOV
# 'In addition to the DEV effort in phase B, in the outline plan that we have submitted to STFC for the later stages of the LUS~or the four years of Phase C and a final 6 staff-years deployed in the early part of Phase D, making a total of 34 FTE years.gdoc'
#  incubator_v3_ajc.docx
# 'Invited participants LSST@Eu4.gsheet'
# 'I plan on participating to April 29 - May 2  bootcamp.gform'
#  iraf.gdoc
#  italyCovid19_0318.gsheet
# 'itg2014 (1)-1.pdf'
#  ItineraryReceipt_24704673402.pdf
#  jdumsATudel.edu.png
#  jldoyleATudel.edu.png
#  jobcandidates/
# 'Job Description-LSSTCSCC 2015-Dec 1.docx'
# 'jobs 2016.gsheet'
# 'Julien Baur 4.1.18.docx'
# 'July2019 LSSTC executive board  SCs Advisory committee meeting.gdoc'
#  kaggle.json
#  kaggleTitanic/
# 'KBO occultations: historical perspective.gdoc'
# 'KD comb scales spreadsheet.gsheet'
# 'Key numbers final.gdoc'
#  KOI42/
#  koranyilet_1_14_20.docx
#  koranyilet_1_14_20.gdoc
#  ksubediATudel.edu.png
#  KyleDavis_ProjectSummary.docx
# 'L14 vs CfA.gsheet'
#  Label-327951343.pdf
#  LA.ipynb
#  LE_proposal2014A/
#  LEsfed.gsheet
#  Letter.gdoc
# 'Letter to recommand dissolution of MB.gdoc'
#  LianEnablingScience2021.gdoc
# 'light echoes.gdraw'
# 'LIHSP 2m observing.gdoc'
# 'LIHSP todo.gdoc'
# 'LINCC meeting 10 02 2019.gdoc'
# 'LINCC TVS applicants.gsheet'
# 'Linear Regression and OLS notes.gdoc'
# 'local info flatiron.gdoc'
#  logs/
# 'Looking Under the Hood of Identity Threat_NW.gslides'
# 'Looking Under the Hood of Identity Threat_NW.pptx'
#  LSST/
# 'LSST 101.gslides'
# 'LSST 2018 TSO session.gdoc'
# 'LSST2019: Sci Collab Plenary Talks Tuesday.gslides'
# 'LSST2019: Sci Collab Plenary Talks Wednesday.gslides'
#  LSST2020_rationale_v02.docx
#  LSST2020_votiricevuti_all.gsheet
#  LSST2020_votiricevuti_all.xlsx
# 'LSST ACCELNET 2020 captions.gdraw'
#  LSSTBrokerWorkshop19/
# 'LSST Cadence Hackathon at the Flatiron Institute.gdoc'
# 'LSST Cadence Hacks CCA, Flatiron Institute.gslides'
# 'LSSTC - Anti-black racism workshop PCW 2021 - emails.gdoc'
#  LSSTCCAHackathon/
# 'LSSTC Executive Board SC committee'/
# 'LSST chairs meeting 10 2018 - .gdoc'
# 'LSST Commissioning Input.gform'
# 'LSSTC SC Advisory committee 07 17 2020 meeting minutes.gdoc'
# 'LSSTC SC Advisory Committee meeting Live Notes.gdoc'
# 'LSST data rates.gsheet'
#  LSSTEu4Abstracts.gdoc
# 'LSSTeu4 Dropbox links.gdoc'
# 'LSST@EU4 feedback form.gform'
# 'LSST@EU4 feedback form (Responses).gsheet'
# 'LSST@Eu4feedback.gslides'
# 'LSST@EU4 opsim.gslides'
# 'LSSTEu4 Parallel Sessions.gsheet'
# 'LSST@Eu4 plan and schedule.gdoc'
# 'LSST@EU4 slides template.gslides'
# 'lsst@eu4 webpate edits.gdoc'
# 'LSST@Europe4 CoC.gdoc'
# 'LSST@Europe4_COC_v1.docx'
# 'LSST@Europe4_COC_v1.gdoc'
# 'LSST@Europe4_COC_v2.docx'
# 'LSST@Europe4 Dinner sign up.gform'
# 'LSST Europe 4 - Registration and Abstract Submission.gform'
# 'LSST@Europe4 Registration (Risposte).gsheet'
# 'LSST@Europe4 unconference topics.gform'
# 'LSST@Europe4 unconference topics (Responses).gsheet'
# 'LSST@Europe4 webpage comments.gdoc'
# 'LSST for-scientists webpages feedback.gform'
# 'LSST IKCC.gdoc'
#  LSST_Invited_Speakers.gdoc
#  lsstlogos.zip
# 'lsstlogos.zip (Unzipped Files)'/
# 'LSST organization.gslides'
# 'lsst.org feedback request .gdoc'
# 'LSST proposed talks.gsheet'
# 'LSST SC chairs call 12 2019.gdoc'
#  LSSTSCCvoteready.csv
#  LSSTSCCvoteready.gsheet
# 'LSST science 101.gslides'
# 'LSST Science Collaborations Status Report - updates August 2019.gslides'
# 'LSST science intro.gslides'
# 'LSSTSNRevolution2017 (1).ppt.gslides'
#  LSSTSNRevolution2017.key
#  LSSTSNRevolution2017.ppt
#  LSSTSNRevolution2017.ppt.gslides
# 'LSST SSSC chair election.gform'
# 'LSST SSSC chair nomination election.gform'
# 'LSST subgroups - Sheet1.gsheet'
# 'LSSTtemplate (1).gslides'
# 'LSSTtemplate (2).gslides'
# 'LSSTtemplate (3).gslides'
# 'LSSTtemplate (4).gslides'
# 'LSSTtemplate (5).gslides'
#  LSSTtemplate.gslides
#  LSSTtemplate.key
# 'LSST TVS'/
# 'LSST TVS chair position.gdoc'
#  LSST-TVS-communicationAugust2016.gdoc
#  LSST_TVS_intro.pdf
# 'LSST_TVS_roadmap (3).pdf'
# 'LSST TVS subgroup proposal.gform'
# 'LSST_TVS _template (1).key'
# 'LSST_TVS _template (1).kth'
# 'LSST_TVS _template (2).key'
# 'LSST_TVS _template.key'
# 'LSST_TVS _template.kth'
# 'lucia seminar participants.gsheet'
#  Lupton_LSST_PSTSAC_02272018_photometry.pdf
# 'lyman14 velocities.gsheet'
#  macho-taos.gsheet
# 'make up exam.gsheet'
#  manTrees.gsheet
# 'Mapping the Periphery and Variability of the Magellanic Clouds Olsen .gdoc'
#  maps/
# 'march 9th meeting notes.gdoc'
#  mariaFilippelliRecommandation.gdoc
#  maximizing-potential-lsst.pdf
#  MDPGeneticAlgorithm/
# 'meeting mimutes template.gdoc'
#  meetingsg.csv
# 'Meeting Slide Template.gslides'
# 'MEMO on Delaware focused predictions of COVID19 infections and hospitalizations.gdoc'
# 'MESSAGES TO PARTICIPANTS.gdoc'
# 'message to participants.gdoc'
# 'meteor showers in 30 sec.gdoc'
# 'metrics from people.gsheet'
#  mguevaraATudel.edu.png
# 'MHealth slides.gdoc'
# 'Microsurveys Draft.gdoc'
# 'midterm hints.gdoc'
# "Ming's Master's Defense.gslides"
# 'ML papers for UD journal club.gsheet'
#  MLPNS/
# 'MLPNS2021 exam signup2.gform'
# 'MLPNS2021 exam signup2 (Responses).gsheet'
# 'MLPNS2021 exam signup.gform'
# 'MLPNS2021 exam signup (Responses).gsheet'
# 'MLPNS topics and p-value.gform'
#  MLTSA/
#  MLTSA2022/
# 'MLTSA 2022 Quiz 10.gform'
# 'MLTSA 2022 Quiz 11.gform'
# 'MLTSA 2022 Quiz 12.gform'
# 'MLTSA 2022 Quiz 9.gform'
#  MLTSA22/
# 'MLTSA 222 quiz 4 (1).gform'
# 'MLTSA 222 quiz 4.gform'
#  mltsalogo.gdraw
# 'MLTSA project proposal - midterm'
# 'MLTSA Quiz 6.gform'
# 'MMA Cyberinfrastructure LSST call.gdoc'
#  Mobility-FBianco.rtf
# 'mockdataforRF (1).xlsx'
#  mockdataforRF.xlsx
#  Modjaz-NYUWomenChallenge.pdf
#  Modjaz-WomenNYUChallenge-Abstract.pdf
# 'monday grades.gsheet'
# 'monthly expenses.gsheet'
# 'movies (1).gsheet'
# 'movies (2).gsheet'
#  movies.csv
#  movies.gsheet
# 'moving expenses.gsheet'
# 'ms (1).pdf'
#  MS#ApJS94897.gdoc
#  MSDS_Applications_F22_Batch_3_assignments.xlsx
#  MSDS-Bylaws_v2.docx
#  ms.pdf
#  muellercATudel.edu.png
#  muhATudel.edu.png
#  MVIMG_20200217_091844.jpg
#  my_apis.csv
#  myapis.csv
#  N0060.pdf
#  N0080.pdf
#  N0139.pdf
#  N0139_thesisa.pdf
#  N0151.pdf
#  N0281.pdf
#  N0298.pdf
#  N0321.pdf
#  N0321_thesisa.pdf
#  N0386.pdf
# 'nam22rubinintro (1).pdf'
#  nam22rubinintro.pdf
# 'NASA letter.gdoc'
#  NASPAA_LOI.gdoc
#  nbs/
# 'nebulae (1).gsheet'
#  nebulae.gdoc
#  nebulae.gsheet
# 'needed for home.gsheet'
# 'Neural Nets: How many hyperparameters? .gdoc'
# 'new house.gsheet'
#  New+york,ny.csv
#  NoAdditionalSingleCopyDoc.gdoc
#  noDIA_PCW2022.gslides
# 'Non-Degenerate Eruptove Variables RoadMap.gdoc'
# 'NSA Problem Set 1_3_6_2020.docx'
# 'NSBP TVS booth.gsheet'
# 'NSF21-523 HDR Data Science Corps Facilities-Equipment-Other Resources.docx'
# 'NSF acknowledgement 2.gdoc'
# 'NSF acknowledgement.gdoc'
# 'NSF BIO_Bianco (1).docx'
# 'NSF BIO_Bianco2018.docx'
# 'NSF BIO_Bianco.docx'
# 'NSF BIO_Bianco.docx.gdoc'
#  nsf-biosketch.docx
# 'NSF -   Budget_Lincoln_University.xlsx'
# 'Nsf career academy.gdoc'
# 'NSF Career Grant proposal, F.gdoc'
# 'NSF CP template_Dobler.docx'
# 'NSF DISN1 Tech metals DRAFT JUNE 18 2020_KFD_XP.docx'
# 'NSF DISN1 Tech metals DRAFT JUNE 18 2020_KFD_XP.gdoc'
# 'NSF DISN1 Tech metals DRAFT JUNE 25_As distributed_KFD_JMK_XP (1).docx'
# 'NSF DISN1 Tech metals DRAFT JUNE 25_As distributed_KFD_JMK_XP.docx'
# 'NSF DISN1 Tech metals DRAFT JUNE 25_As distributed_KFD_JMK_XP.gdoc'
# 'NSFDSC2021 Project Description.pdf'
# 'NSF DSC CoI contribution form.gform'
# 'NSF DSC CoI contribution form (Responses).gsheet'
# 'NSF DSC total personnel.gsheet'
# 'NSF proposals 2020.gsheet'
#  NYCweatherAPI.py
# 'nyu computers .gsheet'
# 'NYU expenses 2013.gsheet'
# 'nyu letter head.gdoc'
#  NYUtemp-3long-BW.dotx
#  NYUtemp-3long-BW.dotx.gdoc
# 'OANDA exchange rate Australian Dollar to USD.gsheet'
#  ObjectIdentification_MinimalInfo.ods
#  ObjectIdentification_MinimalInfo.ods.gsheet
# 'obs astro fall 2013 '/
# 'obs log'/
# 'OBSOLETE NSF21-523 HDR Data Science Corps Facilities-Equipment-Other Resources.docx'
#  occkey2014_annotated.pdf
#  oct08_2013-10-25-175504-6092.raw
# 'Onboarding notes.gdoc'
# 'Opening paper of ApJS (PCW 2021).gslides'
#  osmnx-examples/
# 'OSSOS conf call.gdoc'
#  otherAppsImage.jpg
#  output.pdf
# 'P1060076 (1).jpg'
#  P1060076.jpg
# 'Pages from ABB Book.pdf'
# 'PAGINA 18.pdf'
#  panel.gsheet
# 'papers for Ethics of DS reading group.gdoc'
# 'Partial in person participation LSST@Eu4.gform'
# 'Payment Confirmation.pdf'
#  Pbbfight@
# 'PCW 2020:  August 10-14, 2020 proposed sessions as of 06 02.gsheet'
# 'PCW SCOC 2022 2.gslides'
# 'PCW SCOC 2022.gslides'
# 'PCW SCOC 2022V2.gslides'
# 'peer institutes.gdoc'
#  PEP8_short.gdoc
# 'Pet resume.gdoc'
# 'Petsmart list.gdoc'
#  phasespaceplot/
# 'philly hip bars.gmap'
#  phoebe2/
# 'photo (1).JPG'
#  photo.JPG
#  photometry.pdf
#  photos/
#  phys207/
# 'PHYS207 decolonized science.gform'
# 'PHYS207 decolonized science (Responses).gsheet'
# 'Phys 207 E1.gdoc'
# 'PHYS 207 Exame makeup 3.gdoc'
# 'Physic and Astronomy Tables (1).xlsx'
#  PictureCardsforAphasia-1.pdf
# 'PJ tweets presentation at Marron.gdoc'
# 'PLAsTiCC ICA Renewal.gdoc'
#  PLAsTiCCmetrics.key
# 'Plumes slides.gdoc'
# 'Portions of the Slack conversations that may be useful.gdoc'
# 'Postdoctoral researcher mentoring plan-Bianco LSST SC Accelnet 2020 Supplementary Documentation.gdoc'
#  poster_48x36.gslides
#  poster_48x36.key
# 'Powder room.gdoc'
# 'PRANZO DEL 28.gdoc'
# 'preclass 12.gdoc'
# 'preclass assessment.gsheet'
# 'PRE-CLASS QUIZ PUI2017  Wednesday 10 11 2017.gdoc'
#  prel_prog_lsst_europe4.gdoc
#  prel_prog_lsst_europe4.txt
#  pres19.gsheet
#  PrescriptionDrugsWorksheets-1.zip
#  PreselectionFederica.xlsx
#  PreSelectionResult.xlsx
#  Presentation1.gslides
#  Presentation2.gslides
#  presto-colorEWASS19.key
# 'Preview of Award 2123264 - Annual Project Report.gdoc'
# 'Previous NSF support federica.gdoc'
# 'Primary Department, Unit, or Institute.svg'
# 'Primary Science Collaboration.gform'
# 'Primary Science Collaboration (Responses).gsheet'
# 'Probing the progenitors channels of stripped SN with the CfA SN sample..gdoc'
# 'Project proposal.gdoc'
# 'Prompt Rubin Observatory PCW 2020: Justice, Equity, Diversity, and Inclusion.gform'
# 'Proposal 0331.docx'
# 'Proposal Award Notification-Information Letter 2018-01 Bianco-Street.pdf'
#  proposal_budget_v3.ods
#  proposals/
# 'PST SC-Chairs meeting 03 2018 - Astrometric data products.gdoc'
# 'PST SC-Chairs meeting 07 2020 - OpSims.gdoc'
#  psuATudel.edu.png
# 'PTF09q SN 2009bh.gdoc'
# 'pubpolicy survey.gdoc'
# 'PUI 2015 HW 1 M.gdoc'
# 'PUI 2015 HW 1 W.gdoc'
# 'PUI 2015 HW 3 M.gdoc'
# 'PUI 2015 HW 3 W.gdoc'
# 'PUI 2015 HW 4 W.gdoc'
# 'PUI 2015 HW 5 M W.gdoc'
# 'PUI2016 CLASS GRADES.gsheet'
#  PUI2016_quiz7.gdoc
# 'PUI2016_Tue (1).xlsx'
#  PUI2016_Tue.xlsx
# 'PUI2017final hints.gdoc'
# 'PUI2017final_zz1749 (1).ipynb'
#  PUI2017final_zz1749.ipynb
#  PUI2017grades.gsheet
# 'PUI2017_Morning_HW_1-5_Quiz_Grades (1).xlsx.gsheet'
#  PUI2017_Morning_HW_1-5_Quiz_Grades.xlsx
#  PUI2017_Morning_HW_1-5_Quiz_Grades.xlsx.gsheet
# 'Pui2017 quiz 11 30 PM.gdoc'
# 'PUI2017 quiz 5 Session 1 Wed 10 18 2071.gdoc'
# 'Pui2017 quiz 6 evening.gdoc'
# 'PUI2017quiz Thursday,11 30 2017 PM.gdoc'
# 'PUI2017 Session 1 Thu morning  10 18 2017.gdoc'
# 'PUI2018 Extra Credit Project Proposal.gdoc'
# 'PUI2018 Extra Credit Project Template.gdoc'
# 'PUI Final2018 hints'/
# 'PUI Grading evening.xlsx.gsheet'
# 'PUI midterm 2018'/
#  PUImidtermM2015.gsheet
# 'PUI non CUSP students .gdoc'
# 'Pui quiz 11 am.gdoc'
# 'PUI syllabus Fall 2015.gdoc'
# 'PUS2020 quiz 2.gform'
# 'PUS2020 quiz 2 (Responses).gsheet'
# 'PUS2020 quiz 3 (1).gform'
# 'PUS2020 quiz 3.gform'
# 'PUS2020 quizz 1.gform'
#  PUS2022.gsheet
# 'PUS2022 proposal group.gform'
# 'PUS2022 proposal group (Responses).gsheet'
# 'PUS2022 quiz 3.gform'
# 'PUS2022 quizz 1.gform'
#  PVZLDD.pdf
#  PXL_20220508_135200482.dng
#  PXL_20220508_135200482.MP.jpg
#  PXL_20220516_030858253.dng
#  PXL_20220516_030858253.jpg
#  PXL_20220516_030904932.dng
#  PXL_20220516_030904932.jpg
#  PXL_20220516_140456423.dng
#  PXL_20220516_140456423.MP.jpg
#  PXL_20220516_140507723.dng
#  PXL_20220516_140507723.MP.jpg
#  PXL_20220516_140528323.dng
#  PXL_20220516_140528323.MP.jpg
#  PXL_20220516_140545196.dng
#  PXL_20220516_140545196.MP.jpg
#  PXL_20220516_140813933.dng
#  PXL_20220516_140813933.MP.jpg
#  PXL_20220516_140819422.dng
#  PXL_20220516_140819422.MP.jpg
#  PXL_20220516_140831879.PORTRAIT-01.COVER.jpg
#  PXL_20220516_140842029.PORTRAIT-01.COVER.jpg
#  PXL_20220516_142013358.LS.mp4
#  PXL_20220516_175905422.dng
#  PXL_20220516_175905422.MP.jpg
#  PXL_20220516_175929360.dng
#  PXL_20220516_175929360.MP.jpg
#  PXL_20220516_175945639.dng
#  PXL_20220516_175945639.MP.jpg
#  PXL_20220516_175954640.dng
#  PXL_20220516_175954640.MP.jpg
#  PXL_20220516_180022255.dng
#  PXL_20220516_180022255.MP.jpg
#  PXL_20220516_180023215.dng
#  PXL_20220516_180023215.MP.jpg
#  PXL_20220516_180039220.dng
#  PXL_20220516_180039220.MP.jpg
#  PXL_20220516_180115172.dng
#  PXL_20220516_180115172.MP.jpg
#  PXL_20220516_180203738.LS.mp4
#  PXL_20220516_180206534.dng
#  PXL_20220516_180206534.MP.jpg
#  PXL_20220516_235905862.dng
#  PXL_20220516_235905862.MP.jpg
#  PXL_20220517_002037246.dng
#  PXL_20220517_002037246.MP.jpg
#  PXL_20220517_002038722.dng
#  PXL_20220517_002038722.MP.jpg
#  PXL_20220518_025541871.dng
#  PXL_20220518_025541871.jpg
#  PXL_20220518_025813144.NIGHT.dng
#  PXL_20220518_025813144.NIGHT.jpg
#  PXL_20220518_030039904.jpg
#  PXL_20220518_030040091.jpg
#  PXL_20220518_030040167.jpg
#  PXL_20220518_030040278.jpg
#  PXL_20220518_030040385.jpg
#  PXL_20220518_030040504.jpg
#  PXL_20220518_030048647.dng
#  PXL_20220518_030048647.MP.jpg
#  PXL_20220518_030105974.dng
#  PXL_20220518_030105974.MP.jpg
#  PXL_20220518_030116970.dng
#  PXL_20220518_030116970.MP.jpg
#  PXL_20220518_030123225.dng
#  PXL_20220518_030123225.MP.jpg
#  PXL_20220518_030246415.dng
#  PXL_20220518_030246415.MP.jpg
#  PXL_20220518_030258380.dng
#  PXL_20220518_030258380.MP.jpg
#  PXL_20220518_030304292.dng
#  PXL_20220518_030304292.MP.jpg
#  PXL_20220518_030347228.dng
#  PXL_20220518_030347228.jpg
#  PXL_20220518_030409798.dng
#  PXL_20220518_030409798.jpg
#  PXL_20220518_030421128.dng
#  PXL_20220518_030421128.MP.jpg
#  PXL_20220518_030422521.dng
#  PXL_20220518_030422521.MP.jpg
#  PXL_20220518_030452712.dng
#  PXL_20220518_030452712.MP.jpg
#  PXL_20220518_030457892.dng
#  PXL_20220518_030457892.MP.jpg
#  PXL_20220518_030503759.dng
#  PXL_20220518_030503759.MP.jpg
#  PXL_20220518_030535773.dng
#  PXL_20220518_030535773.MP.jpg
#  PXL_20220518_030538755.dng
#  PXL_20220518_030538755.MP.jpg
#  PXL_20220518_030548807.jpg
#  PXL_20220518_030728453.dng
#  PXL_20220518_030728453.MP.jpg
#  PXL_20220518_030729791.dng
#  PXL_20220518_030729791.MP.jpg
#  PXL_20220518_030731580.dng
#  PXL_20220518_030731580.MP.jpg
#  PXL_20220518_031111017.dng
#  PXL_20220518_031111017.MP.jpg
#  PXL_20220518_031120194.dng
#  PXL_20220518_031120194.MP.jpg
#  PXL_20220518_031140266.dng
#  PXL_20220518_031140266.jpg
#  PXL_20220518_031141992.dng
#  PXL_20220518_031141992.MP.jpg
#  PXL_20220518_031148367.dng
#  PXL_20220518_031148367.MP.jpg
#  PXL_20220518_174317337.jpg
#  PXL_20220518_174319788.dng
#  PXL_20220518_174319788.MP.jpg
#  PXL_20220518_174404733.jpg
#  PXL_20220518_174405054.jpg
#  __pycache__/
# 'pymcz referee report .gdoc'
# 'python bootcamp entry form.gform'
# 'Python bootcamp feedback 2022.gform'
# 'Python bootcamp.gform'
# 'Python bootcamp (Responses).gsheet'
#  Q1_DE-AR0000886_NYUBianco.key
#  Q3_DE-AR0000886_NYUBianco.key.zip
#  Q5_DE-AR0000886_NYUBianco.pdf
#  qamarATudel.edu.png
# 'Question ID:   246.gdoc'
# 'Questionnaire (R).docx'
# 'Questions about RSP from TVS software and IDAC developers.gdoc'
#  RAFTSNSF2022/
# 'RAFT timeline.gsheet'
#  RagostaEnablingScience2021.gdoc
#  random_submission.zip
# 'ranking startup.gdoc'
#  ranks.gsheet
#  RBRdistribute.ipynb
#  ReadingComprehensionforAphasia-1.pdf
# 'reading list.gdoc'
#  readligo.py
#  references/
# 'References EPSCoR fellowship.gdoc'
#  references.gdoc
#  register.tsv
# 'Relevant items from TEAM-UP report.gdoc'
# 'repush date.PNG'
# 'research active WiPA-UD.gsheet'
# 'ResearchSummary blavatnikaward .gdoc'
# 'reserved spots ARW - PCW2021.gslides'
#  residplot.py
# 'Response to Anonymous reviewer #1:.gdoc'
# 'Response to Anonymous reviewer #2.gdoc'
#  resume.gdoc
#  Resume.gdoc
# 'REVIEW ASSIGNMENTS.gsheet'
# 'Review or resubmission.gdoc'
#  rf.10813433.pdf
# 'RF meeting.gdoc'
#  Rhodes_SN.key
#  rooet.png
#  root.png
#  rstreet_support_letter_signed.pdf
# 'rubinaas237mmatdamediaws (1).pdf'
#  rubinaas237mmatdamediaws_FBBianco.pdf
# 'RubinEuclid WG SC nominees.gsheet'
# 'Rubin-Euclid Working Group SC representatives.gdoc'
#  rubinlsst2022_SCs.pdf
# 'Rubin LSST links for NSBP.gsheet'
# 'Rubin LSST Science Collaboration Coordinator - Voter Activity Logs (1649345680)-1.gsheet'
# 'Rubin Observatory PCW 2020: Justice, Equity, Diversity, and Inclusion (Responses).gsheet'
# 'Rubin PCW2020 DEI session plan.gdoc'
# 'Rubin Project and Community Workshop anti-racism workshop interest form. (Responses) - Form Responses 1 (1).csv'
# 'Rubin Project and Community Workshop anti-racism workshop interest form. (Responses) - Form Responses 1.csv'
# 'Rubin-related Initiatives Toward Diversity, Equity, and Inclusion.gslides'
# 'SAC-SCOC review.gslides'
# 'SAC-SCOC review.key'
#  sample_submission.csv.zip
# 'Santa Fe Institute App.docx'
# 'Santa Fe Institute App.docx.gdoc'
# 'Saved Rubin PCW 2020 - DEI Session.gslides'
#  scabreraATudel.edu.png
# 'SC Advisory Committee Charge 08jun20 LM.gdoc'
#  scan015.pdf
# 'SC Chairs CEC thoughts.gdoc'
# 'SC chairs meeting 05 05 2020.gdoc'
# 'SC Chairs meeting August 30th 2019.gdoc'
# 'SC chairs meeting.gdoc'
# 'SC-Chairs meeting March 24 2021.gdoc'
# 'SC content.gdoc'
# 'SC Coord 2021 invoice.gsheet'
# 'SC Coord 2021 invoice.xlsx'
# 'SC coord election messages.gdoc'
# 'SC coordinator FBB.gdoc'
# 'Science Collaborations.pptx'
# 'Science Collaborations.pptx.gslides'
# 'Science Collaboration  White Paper Responses Federica Bianco Science Collaborations Coordinator  and the Science Collaboration Reps.gslides'
# 'Science Collaboration  White Paper Responses .gslides'
# 'science train.001.jpg'
# 'SCiMMA Data management, communication, and collaboration meeting 1.gdoc'
#  SCOC2023.gsheet
# 'SCOC Euclid DDF field selection recommendation.gdoc'
# 'SCOC letter draft - 2023 recruitment.gdoc'
# 'SCOC meeting 10 28 minutes for public release.gdoc'
# 'SCOC_WS3_Day1 (1).mp4'
#  SCOC_WS3_Day1.mp4
#  SCOC_WS3_Day2.mp4
# 'SCOC ws3 intro day2.gslides'
# 'SCOC ws3 intro.gslides'
#  SCOPATONS:.gdoc
# 'SC plenary Rubin PCW 2021.gslides'
#  scraigATudel.edu.png
# 'Screen Shot 2014-06-23 at 3.53.47 PM.png'
# 'Screen Shot 2014-08-23 at 5.40.18 PM.png'
# 'Screen Shot 2015-04-23 at 3.37.05 PM.png'
# 'Screen Shot 2015-04-23 at 3.38.16 PM.png'
# 'Screen Shot 2016-01-17 at 5.21.42 PM.png'
# 'Screen Shot 2018-06-08 at 11.44.56 PM.png'
# 'Screen Shot 2019-05-02 at 11.39.54 PM.png'
# 'Screen Shot 2020-08-29 at 9.55.12 PM.png'
# 'Screen Shot 2020-10-26 at 12.28.46 PM.png'
# 'Screen Shot 2022-09-22 at 3.11.52 PM.png'
# 'Screen Shot 2022-09-22 at 3.12.07 PM.png'
# 'Screen Shot 2022-09-23 at 2.08.08 PM.png'
# 'SC report  LSSTC October 2019.gslides'
# 'SC representatives on CEC.gsheet'
# 'script TVS.gdoc'
# 'SCs DEI council.gsheet'
# 'SC speakers PCW 2019.gsheet'
# 'SC webpage.gdoc'
#  seamlesslyPoor.ipynb
# 'Searching for white dwarf transits with LSST  - Silvotti.gdoc'
#  SearchResults.csv
#  SearchResults.gsheet
#  sections.gsheet
#  Sedna_2013-01-10T05h09m02s.jpg
#  Sedna_2013-01-13T12h25m42s.jpg
#  selectTalksDSIS2019/
#  sentimentanal/
#  sentimentanalysis/
# 'SETI LSST budget.gsheet'
# 'setting up my new mac mountainlion and ElCapitan.gdoc'
# 'shi recommendation.gdoc'
# 'Shutter setup'/
#  shutterstock_483529342.jpg
# 'SierraLeone_urban_observatory (1).pdf'
#  SierraLeone_urban_observatory.pdf
#  sig.gdraw
#  sky_separation.py
# 'slide for facilities.gslides'
# 'slides and talks'/
#  Sloan2021.gdoc
#  sloth.mp4
#  SLSC.gdraw
#  smithemATudel.edu.png
#  smwlvsticker.gdraw
#  SN07gr.photometry_derived.png
#  sn1990B_Ic-norm_4_z_comp0001_snidflux.ps
#  sn2005eo_flux.dat
# 'SNacrossSCs website.gdoc'
#  sn.gdoc
#  SN-syllabus.doc.gdoc
#  SN_w_max_Fe_measured.gdoc
#  SNYUqrcode.png
# 'Sogno Berlino.gdoc'
#  SOIsdiagrams.gdoc
#  SOMAYEH_COA_2021.xlsx
# 'Somayeh Khakpash Offer Letter.rtf.gdoc'
#  sonification.drawio
# 'south africa.gdoc'
# 'Southern Poverty Law Center'@
# 'sparring class.docx'
# 'sparring class.pages'
# 'sparring class.pdf'
#  SpeechTherapyActivityforAphasiaWordRecall-1.pdf
# 'SPL DATAKIND.gdoc'
#  spm/
# 'spring hackaton.gdoc'
# 'SQUID-Bike, Street Quality IDentification for citywide Bike Lane infrastructure (2).pdf'
#  sseadrowATudel.edu.png
# 'SSSC participants.gsheet'
#  ssscsticker.gdraw
# 'SSSC Working Group Leads and Publication Coordinator Elections  (Responses).gsheet'
#  startupsUD.ipynb
# 'Statement of work.gdoc'
#  Stellar_Evolution_large.jpg
#  STNat/
# 'stripped SN date of max from MC resampling.gdoc'
# 'subgroup presentations.gsheet'
# 'Suggestions form: Rubin Observatory PCW 2020: Justice, Equity, Diversity, and Inclusion.gform'
#  summary_2022_04_28.csv
#  summary_2022_04_28.gsheet
# 'Summary Sci Collab activities and LSSTPCW2019 SC Plenary Talks.gslides'
# 'summer 2022 meetings and conferences.gsheet'
#  Supernovae.zip
# 'Swift Cycle 11 NDA.pdf'
# 'Syllabus: Foundations of Data Science for Everyone.gdoc'
# 'Symposium 2020.gsheet'
# 'Synopsis of current SCOC recommendations (for internal use).gdoc'
#  _system_appendPDF_proof_hi.pdf
# 'TAC report FED 07&17.gdoc'
# 'Talking Guerilla Science.pdf'
#  talks/
# 'talk uploads.gsheet'
#  tanyanesATudel.edu.png
# 'Target  of  Opportunity  Observations  ofGravitational  Wave  Events  with  LSST Margutti.gdoc'
# 'TAs 2018.gsheet'
#  taxes19/
#  taxes20/
# 'TDEs  with  LSST Bricman.gdoc'
# 'teamup discussions resources.gdoc'
# 'TEAM-UP section summaries.gdoc'
# 'TED fellow space show'/
# 'TED slides'/
# 'Template Rubin PCW 2020 - DEI Session.gslides'
#  test.csv
#  test_dir/
#  test_python_access.gsheet
#  test_set_sample.csv.zip
#  test.zip
# 'The  Diverse  Science  Return  from  a  Wide-AreaSurvey  of  the  Galactic  Plane  - Street.gdoc'
# 'The missing link between Theory and Observations.gdoc'
# 'The Second SCOC-Science Collaborations Workshop (virtual).gdoc'
# 'The story of these Nobel Prize begins in the early 1900 with Albert Einstein'\''s formulations of the special and general theor~ies that had to be described in order to understand the significance of The discoveries that were recognized with this price.gdoc'
# 'The Zen of Python.gdoc'
# 'This project will work to assess the viability of social media, particularly twitter, as a meter to measure the response of the population to policy implementation in the prosecutorial justice sector.gdoc'
#  Timeline_10Nov2021.docx
# 'Tips on clustering.gdoc'
#  Titanic/
#  TitanicKaggleData/
#  TitanicTree
#  TitanicTree.pdf
#  tl_2018_10_tract.cpg
#  tl_2018_10_tract.dbf
#  tl_2018_10_tract.prj
#  tl_2018_10_tract.shp
#  tl_2018_10_tract.shp.ea.iso.xml
#  tl_2018_10_tract.shp.iso.xml
#  tl_2018_10_tract.shx
#  tl_2018_10_tract.zip
#  tl_2018_10_tract.zip.1
#  tl_2018_10_tract.zip.2
#  tl_2018_10_tract.zip.3
#  tl_2018_10_tract.zip.4
#  tl_2018_10_tract.zip.5
#  tmeg.png
# 'tmp (1).csv'
# 'tmp (1).gsheet'
# 'tmp (2).gsheet'
#  tmp3
# 'tmp3 (1).csv'
#  tmp3.csv
#  tmp.csv
#  tmp.doc
#  tmp.gsheet
#  tmp.key
#  tmptmp.doc
#  tobacco@
# 'TOM added to slack.gdoc'
# 'TOM proposals FBB.gdoc'
#  toms_and_brokers_lsst2018_fed.pdf
#  total_Ib_3_4_2_dh.ps
#  train.csv
#  training_set.csv.zip
#  training_set_metadata.csv
#  training_solutions_rev1.csv
#  training_solutions_rev1.zip
#  training.zip
# 'transient chapter tables.gdoc'
# 'Transients OpSim V2.1 meeting.gdoc'
#  transients_standalone.pdf
# 'Transients & Variable Stars SC - Blending impacts & metrics.gslides'
# 'Travel Expense Pre Authorization Form.docx'
# 'T-Shirt Sign Up (1).gform'
# 'T-Shirt Sign Up.gform'
# 'TVS 2019 Task Force Sign up.gform'
# 'TVS call 03 05 2018.gdoc'
# 'TVS Catalyst fellowship mentors.gform'
# 'TVS Catalyst fellowship mentors (Responses).gsheet'
# 'TVS conf call 01 23 2019.gdoc'
# 'TVS DDP-Euclid form.gform'
# 'TVS DDP-Euclid form (Responses).gsheet'
# 'TVS DP0 delegates.gform'
# 'TVS_full_list (1).gsheet'
# 'TVS_full_list_contact (1).csv'
# 'TVS_full_list_contact (1).csv.gsheet'
# 'TVS_full_list_contact (2).csv'
# 'TVS_full_list_contact (2).csv.gsheet'
#  TVS_full_list_contact.csv
#  TVS_full_list_contact.csv.gsheet
#  TVS_full_list.gsheet
#  TVS_full_list.numbers
#  TVS_full_list.xlsx
#  TVS_Getting_Started_Guide.pdf
#  TVSlogo.gdraw
#  TVSlogolabel.gdraw
# 'TVS LSST@asia.gslides'
# 'TVS LSST cadence proposals.gdoc'
# 'TVS LSST call 10 20.gdoc'
# 'TVS metrics and survey cadence proposals.gslides'
# 'TVS NSF AAG proposal.gsheet'
# 'TVS publication report.gform'
# 'TVS roadmap blur.gdoc'
# 'TVS Roadmap Meeting Ride Share sign up.gsheet'
# 'TVS roadmap subgroups.gsheet'
# 'TVS Rodad Map March 2016 Schedule.gdoc'
# 'TVS SC petition to SAC.gdoc'
# 'TVS-SMWLV meeting and hackathon 2019.gform'
# 'TVS-SMWLV meeting and hackathon 2019 (Responses).gsheet'
# 'TVS software proposal.gform'
# 'TVS software proposal (Responses) (1).gsheet'
# 'TVS software proposal (Responses).gsheet'
# 'TVS  Software Task Force GANTT CHART.gsheet'
# 'TVS Software workshop II - Agenda.gsheet'
# 'TVS Software Workshop II.gsheet'
#  tvssticker.gdraw
# 'TVS Subgroup Leads Telecon 2019 July 1st.gdoc'
# 'TVS subgroup proposal.gform'
# 'TVS Subgroup task force.gslides'
# 'TVS task force proposal 2019.gform'
# 'TVS task force proposal 2019 (Responses).gsheet'
# 'TVS White Paper Submissions.gsheet'
# 'TVS WP submissions.gsheet'
#  ucsc22.pdf
#  udclass.key
# 'UD Computational Social Science Symposium.gform'
#  UDCovidDataTimeSeries_AllHospitalizations_20200405.xlsx
#  UDCovidDataTimeSeries_CurrentlyHospitalized_20200404.xlsx
#  UDCOVIDhack/
# 'UD Data Science Symporium Exit Survey 2019DSI.gform'
# 'UD Data Science Symporium Exit Survey 2019DSI (Responses).gsheet'
#  UDDSC.pdf
#  udel-abstract92921.docx
#  udel-bio.docx
# 'UDel DPA DI&C committee nominations.gform'
# 'UD Fall hackathon 2019.gdoc'
# 'UD hackathon proposal.gdoc'
# 'UD POTU Journal Club Responses.gsheet'
# 'UD startup flexibility.gsheet'
#  UI4_PUI2018.key
# 'Unique  Science  from  a  Coordinated  LSST-WFIRSTSurvey  of  the  Galactic  Bulge Street.gdoc'
# 'unitedtix I owe you 2019.gsheet'
#  Untitled
#  Untitled0.ipynb
#  Untitled1.ipynb
#  Untitled2.ipynb
# 'Untitled Diagram (1).drawio'
# 'Untitled Diagram (1).html'
# 'Untitled Diagram (2).drawio'
# 'Untitled Diagram (2).html'
# 'Untitled Diagram (3).drawio'
# 'Untitled Diagram (3).html'
# 'Untitled Diagram (4).drawio'
# 'Untitled Diagram (4).html'
# 'Untitled Diagram (5).drawio'
# 'Untitled Diagram (5).html'
# 'Untitled Diagram (6).drawio'
# 'Untitled Diagram (7).drawio'
# 'Untitled Diagram (8).drawio'
# 'Untitled Diagram.drawio'
# 'Untitled Diagram.html'
# 'Untitled document (100).gdoc'
# 'Untitled document (101).gdoc'
# 'Untitled document (102).gdoc'
# 'Untitled document (103).gdoc'
# 'Untitled document (104).gdoc'
# 'Untitled document (105).gdoc'
# 'Untitled document (106).gdoc'
# 'Untitled document (107).gdoc'
# 'Untitled document (108).gdoc'
# 'Untitled document (109).gdoc'
# 'Untitled document (10).gdoc'
# 'Untitled document (110).gdoc'
# 'Untitled document (111).gdoc'
# 'Untitled document (112).gdoc'
# 'Untitled document (113).gdoc'
# 'Untitled document (114).gdoc'
# 'Untitled document (115).gdoc'
# 'Untitled document (116).gdoc'
# 'Untitled document (117).gdoc'
# 'Untitled document (118).gdoc'
# 'Untitled document (119).gdoc'
# 'Untitled document (11).gdoc'
# 'Untitled document (120).gdoc'
# 'Untitled document (121).gdoc'
# 'Untitled document (122).gdoc'
# 'Untitled document (123).gdoc'
# 'Untitled document (124).gdoc'
# 'Untitled document (125).gdoc'
# 'Untitled document (126).gdoc'
# 'Untitled document (127).gdoc'
# 'Untitled document (128).gdoc'
# 'Untitled document (129).gdoc'
# 'Untitled document (12).gdoc'
# 'Untitled document (130).gdoc'
# 'Untitled document (131).gdoc'
# 'Untitled document (132).gdoc'
# 'Untitled document (133).gdoc'
# 'Untitled document (134).gdoc'
# 'Untitled document (135).gdoc'
# 'Untitled document (136).gdoc'
# 'Untitled document (137).gdoc'
# 'Untitled document (138).gdoc'
# 'Untitled document (139).gdoc'
# 'Untitled document (13).gdoc'
# 'Untitled document (140).gdoc'
# 'Untitled document (141).gdoc'
# 'Untitled document (142).gdoc'
# 'Untitled document (143).gdoc'
# 'Untitled document (144).gdoc'
# 'Untitled document (145).gdoc'
# 'Untitled document (146).gdoc'
# 'Untitled document (147).gdoc'
# 'Untitled document (148).gdoc'
# 'Untitled document (149).gdoc'
# 'Untitled document (14).gdoc'
# 'Untitled document (150).gdoc'
# 'Untitled document (151).gdoc'
# 'Untitled document (152).gdoc'
# 'Untitled document (153).gdoc'
# 'Untitled document (154).gdoc'
# 'Untitled document (155).gdoc'
# 'Untitled document (156).gdoc'
# 'Untitled document (157).gdoc'
# 'Untitled document (158).gdoc'
# 'Untitled document (159).gdoc'
# 'Untitled document (15).gdoc'
# 'Untitled document (160).gdoc'
# 'Untitled document (161).gdoc'
# 'Untitled document (162).gdoc'
# 'Untitled document (163).gdoc'
# 'Untitled document (164).gdoc'
# 'Untitled document (165).gdoc'
# 'Untitled document (166).gdoc'
# 'Untitled document (167).gdoc'
# 'Untitled document (168).gdoc'
# 'Untitled document (169).gdoc'
# 'Untitled document (16).gdoc'
# 'Untitled document (170).gdoc'
# 'Untitled document (171).gdoc'
# 'Untitled document (172).gdoc'
# 'Untitled document (173).gdoc'
# 'Untitled document (174).gdoc'
# 'Untitled document (175).gdoc'
# 'Untitled document (176).gdoc'
# 'Untitled document (177).gdoc'
# 'Untitled document (178).gdoc'
# 'Untitled document (179).gdoc'
# 'Untitled document (17).gdoc'
# 'Untitled document (180).gdoc'
# 'Untitled document (181).gdoc'
# 'Untitled document (182).gdoc'
# 'Untitled document (183).gdoc'
# 'Untitled document (184).gdoc'
# 'Untitled document (185).gdoc'
# 'Untitled document (186).gdoc'
# 'Untitled document (187).gdoc'
# 'Untitled document (188).gdoc'
# 'Untitled document (189).gdoc'
# 'Untitled document (18).gdoc'
# 'Untitled document (190).gdoc'
# 'Untitled document (191).gdoc'
# 'Untitled document (192).gdoc'
# 'Untitled document (193).gdoc'
# 'Untitled document (194).gdoc'
# 'Untitled document (195).gdoc'
# 'Untitled document (196).gdoc'
# 'Untitled document (197).gdoc'
# 'Untitled document (198).gdoc'
# 'Untitled document (199).gdoc'
# 'Untitled document (19).gdoc'
# 'Untitled document (1).gdoc'
# 'Untitled document (200).gdoc'
# 'Untitled document (201).gdoc'
# 'Untitled document (202).gdoc'
# 'Untitled document (203).gdoc'
# 'Untitled document (204).gdoc'
# 'Untitled document (205).gdoc'
# 'Untitled document (206).gdoc'
# 'Untitled document (207).gdoc'
# 'Untitled document (208).gdoc'
# 'Untitled document (209).gdoc'
# 'Untitled document (20).gdoc'
# 'Untitled document (210).gdoc'
# 'Untitled document (211).gdoc'
# 'Untitled document (212).gdoc'
# 'Untitled document (213).gdoc'
# 'Untitled document (214).gdoc'
# 'Untitled document (215).gdoc'
# 'Untitled document (216).gdoc'
# 'Untitled document (217).gdoc'
# 'Untitled document (218).gdoc'
# 'Untitled document (21).gdoc'
# 'Untitled document (22).gdoc'
# 'Untitled document (23).gdoc'
# 'Untitled document (24).gdoc'
# 'Untitled document (25).gdoc'
# 'Untitled document (26).gdoc'
# 'Untitled document (27).gdoc'
# 'Untitled document (28).gdoc'
# 'Untitled document (29).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (30).gdoc'
# 'Untitled document (31).gdoc'
# 'Untitled document (32).gdoc'
# 'Untitled document (33).gdoc'
# 'Untitled document (34).gdoc'
# 'Untitled document (35).gdoc'
# 'Untitled document (36).gdoc'
# 'Untitled document (37).gdoc'
# 'Untitled document (38).gdoc'
# 'Untitled document (39).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (40).gdoc'
# 'Untitled document (41).gdoc'
# 'Untitled document (42).gdoc'
# 'Untitled document (43).gdoc'
# 'Untitled document (44).gdoc'
# 'Untitled document (45).gdoc'
# 'Untitled document (46).gdoc'
# 'Untitled document (47).gdoc'
# 'Untitled document (48).gdoc'
# 'Untitled document (49).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (50).gdoc'
# 'Untitled document (51).gdoc'
# 'Untitled document (52).gdoc'
# 'Untitled document (53).gdoc'
# 'Untitled document (54).gdoc'
# 'Untitled document (55).gdoc'
# 'Untitled document (56).gdoc'
# 'Untitled document (57).gdoc'
# 'Untitled document (58).gdoc'
# 'Untitled document (59).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (60).gdoc'
# 'Untitled document (61).gdoc'
# 'Untitled document (62).gdoc'
# 'Untitled document (63).gdoc'
# 'Untitled document (64).gdoc'
# 'Untitled document (65).gdoc'
# 'Untitled document (66).gdoc'
# 'Untitled document (67).gdoc'
# 'Untitled document (68).gdoc'
# 'Untitled document (69).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (70).gdoc'
# 'Untitled document (71).gdoc'
# 'Untitled document (72).gdoc'
# 'Untitled document (73).gdoc'
# 'Untitled document (74).gdoc'
# 'Untitled document (75).gdoc'
# 'Untitled document (76).gdoc'
# 'Untitled document (77).gdoc'
# 'Untitled document (78).gdoc'
# 'Untitled document (79).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document (80).gdoc'
# 'Untitled document (81).gdoc'
# 'Untitled document (82).gdoc'
# 'Untitled document (83).gdoc'
# 'Untitled document (84).gdoc'
# 'Untitled document (85).gdoc'
# 'Untitled document (86).gdoc'
# 'Untitled document (87).gdoc'
# 'Untitled document (88).gdoc'
# 'Untitled document (89).gdoc'
# 'Untitled document (8).gdoc'
# 'Untitled document (90).gdoc'
# 'Untitled document (91).gdoc'
# 'Untitled document (92).gdoc'
# 'Untitled document (93).gdoc'
# 'Untitled document (94).gdoc'
# 'Untitled document (95).gdoc'
# 'Untitled document (96).gdoc'
# 'Untitled document (97).gdoc'
# 'Untitled document (98).gdoc'
# 'Untitled document (99).gdoc'
# 'Untitled document (9).gdoc'
# 'Untitled document.gdoc'
# 'Untitled drawing (1).gdraw'
# 'Untitled drawing (2).gdraw'
# 'Untitled drawing.gdraw'
# 'Untitled folder'/
# 'Untitled form (10).gform'
# 'Untitled form (11).gform'
# 'Untitled form (12).gform'
# 'Untitled form (13).gform'
# 'Untitled form (14).gform'
# 'Untitled form (15).gform'
# 'Untitled form (16).gform'
# 'Untitled form (1).gform'
# 'Untitled form (2).gform'
# 'Untitled form (3).gform'
# 'Untitled form (4).gform'
# 'Untitled form (5).gform'
# 'Untitled form (6).gform'
# 'Untitled form (7).gform'
# 'Untitled form (8).gform'
# 'Untitled form (9).gform'
# 'Untitled form.gform'
# 'Untitled Jam.gjam'
# 'Untitled presentation (10).gslides'
# 'Untitled presentation (11).gslides'
# 'Untitled presentation (12).gslides'
# 'Untitled presentation (13).gslides'
# 'Untitled presentation (14).gslides'
# 'Untitled presentation (15).gslides'
# 'Untitled presentation (16).gslides'
# 'Untitled presentation (17).gslides'
# 'Untitled presentation (18).gslides'
# 'Untitled presentation (1).gslides'
# 'Untitled presentation (2).gslides'
# 'Untitled presentation (3).gslides'
# 'Untitled presentation (4).gslides'
# 'Untitled presentation (5).gslides'
# 'Untitled presentation (6).gslides'
# 'Untitled presentation (7).gslides'
# 'Untitled presentation (8).gslides'
# 'Untitled presentation (9).gslides'
# 'Untitled presentation.gslides'
# 'Untitled spreadsheet (10).gsheet'
# 'Untitled spreadsheet (11).gsheet'
# 'Untitled spreadsheet (12).gsheet'
# 'Untitled spreadsheet (13).gsheet'
# 'Untitled spreadsheet (14).gsheet'
# 'Untitled spreadsheet (15).gsheet'
# 'Untitled spreadsheet (16).gsheet'
# 'Untitled spreadsheet (17).gsheet'
# 'Untitled spreadsheet (18).gsheet'
# 'Untitled spreadsheet (19).gsheet'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled Spreadsheet (1).gsheet'
# 'Untitled spreadsheet (20).gsheet'
# 'Untitled spreadsheet (21).gsheet'
# 'Untitled spreadsheet (22).gsheet'
# 'Untitled spreadsheet (23).gsheet'
# 'Untitled spreadsheet (24).gsheet'
# 'Untitled spreadsheet (25).gsheet'
# 'Untitled spreadsheet (26).gsheet'
# 'Untitled spreadsheet (27).gsheet'
# 'Untitled spreadsheet (28).gsheet'
# 'Untitled spreadsheet (29).gsheet'
# 'Untitled spreadsheet (2).gsheet'
# 'Untitled Spreadsheet (2).gsheet'
# 'Untitled spreadsheet (30).gsheet'
# 'Untitled spreadsheet (31).gsheet'
# 'Untitled spreadsheet (32).gsheet'
# 'Untitled spreadsheet (33).gsheet'
# 'Untitled spreadsheet (34).gsheet'
# 'Untitled spreadsheet (35).gsheet'
# 'Untitled spreadsheet (36).gsheet'
# 'Untitled spreadsheet (37).gsheet'
# 'Untitled spreadsheet (38).gsheet'
# 'Untitled spreadsheet (39).gsheet'
# 'Untitled spreadsheet (3).gsheet'
# 'Untitled spreadsheet (40).gsheet'
# 'Untitled spreadsheet (41).gsheet'
# 'Untitled spreadsheet (42).gsheet'
# 'Untitled spreadsheet (43).gsheet'
# 'Untitled spreadsheet (44).gsheet'
# 'Untitled spreadsheet (45).gsheet'
# 'Untitled spreadsheet (46).gsheet'
# 'Untitled spreadsheet (47).gsheet'
# 'Untitled spreadsheet (48).gsheet'
# 'Untitled spreadsheet (49).gsheet'
# 'Untitled spreadsheet (4).gsheet'
# 'Untitled spreadsheet (50).gsheet'
# 'Untitled spreadsheet (51).gsheet'
# 'Untitled spreadsheet (52).gsheet'
# 'Untitled spreadsheet (53).gsheet'
# 'Untitled spreadsheet (54).gsheet'
# 'Untitled spreadsheet (55).gsheet'
# 'Untitled spreadsheet (56).gsheet'
# 'Untitled spreadsheet (57).gsheet'
# 'Untitled spreadsheet (58).gsheet'
# 'Untitled spreadsheet (59).gsheet'
# 'Untitled spreadsheet (5).gsheet'
# 'Untitled spreadsheet (60).gsheet'
# 'Untitled spreadsheet (61).gsheet'
# 'Untitled spreadsheet (62).gsheet'
# 'Untitled spreadsheet (63).gsheet'
# 'Untitled spreadsheet (64).gsheet'
# 'Untitled spreadsheet (65).gsheet'
# 'Untitled spreadsheet (66).gsheet'
# 'Untitled spreadsheet (67).gsheet'
# 'Untitled spreadsheet (6).gsheet'
# 'Untitled spreadsheet (7).gsheet'
# 'Untitled spreadsheet (8).gsheet'
# 'Untitled spreadsheet (9).gsheet'
# 'Untitled spreadsheet.gsheet'
# 'Untitled Spreadsheet.gsheet'
# 'unVEil  the  darknesS  of  The  gAlactic  buLgE  (VESTALE) Bono   DallOra.gdoc'
# 'UO data acquisition.gsheet'
# 'UO Hypertemporal photometry of City Lights.gdoc'
# 'UO storage.gsheet'
# 'Urban Metabolism studies: detection and tracking of building generated pollutant plumes.gdoc'
# 'US curriculum meeting.gdoc'
# 'UW (1).zip'
#  UW.zip
#  vars.env
#  vdamicoATudel.edu.png
# 'vegan and veggy meals in philly.gmap'
#  velocity_2.png
#  velocity.pdf
#  ViaggioUSA2022/
#  VID_20140222_151219.mp4
#  VID_20190806_172853.mp4
#  VID_20200201_134435~3.mp4
# 'Vira comet.gdoc'
# 'Vision for a Data Science curriculum for Public Service.gdoc'
#  vphfe.gsheet
# 'wednesday grades.gsheet'
# 'Welcome and Logistics .gslides'
# 'Welcome message draft.gdoc'
# 'well sampled SESN lightcurves.gsheet'
#  wessoccs.zip
# 'Wiki to HTML flow.gdoc'
# 'Willman Cover Letter CCA 2021.v4.docx'
# 'Willman DPA.gslides'
# 'Willman - proposing affiliation to DPA.gdoc'
# 'Wilman endorsement.gdoc'
# 'WIPA-UD .gform'
#  workspaceswDECAMeta03a3.mov
# 'Wsession HW1-5.gsheet'
# 'WVSGC Hackweek Invite DE.docx'
#  XHTDEE.pdf
#  XiaolongDSIsymposiumposter.gslides
#  yana_fdnyshow2018.mov
#  Yuqian_appendicxA-D.gdoc
# 'yuqian reference letter.gdoc'
# 'ZHANG Lingyi Resume.pdf'

# %%
ls kag*
# Out:
# kaggle.json
#
# kaggleTitanic:
# gender_submission.csv  TitanicTree      titanic.zip
# test.csv               TitanicTree.pdf  train.csv

# %% [markdown]
# commenting the next cell cause I have alredy run the notebook and that needs to be done only once

# %%
#!chmod 600 kaggle.json

# %%
import json
envs = json.load(open("kaggle.json", "r"))

# %%
import os
os.environ["KAGGLE_USERNAME"] = envs['username']
os.environ["KAGGLE_KEY"] = envs['key']

# %%
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.64.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (6.1.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2022.9.24)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)

# %%
# !kaggle datasets list
# Out:
# ref                                                             title                                       size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  -----------------------------------------  -----  -------------------  -------------  ---------  ---------------
# akshaydattatraykhare/diabetes-dataset                           Diabetes Dataset                             9KB  2022-10-06 08:55:25          14340        433  1.0
# swaptr/layoffs-2022                                             Layoffs 2022                                29KB  2022-11-16 20:46:46            762         27  1.0
# akshaydattatraykhare/data-for-admission-in-the-university       Data for Admission in the University         4KB  2022-10-27 11:05:45           3250         72  1.0
# aneesayoub/world-universities-ranking-2022                      World Universities Ranking 2022             41KB  2022-11-17 03:47:37            856         25  0.9117647
# whenamancodes/covid-19-coronavirus-pandemic-dataset             COVID -19 Coronavirus Pandemic Dataset      11KB  2022-09-30 04:05:11          11016        345  1.0
# thedevastator/240000-household-electricity-consumption-records  Household Electricity Consumption            3MB  2022-10-24 01:22:40           1046         31  1.0
# whenamancodes/credit-card-customers-prediction                  Credit Card Customers Prediction           379KB  2022-10-30 13:03:27           2355         59  1.0
# thedevastator/latest-licensed-playstation-games-in-japan        PlayStation Games                           53KB  2022-11-09 02:51:20            560         29  0.9411765
# hasibalmuzdadid/global-air-pollution-dataset                    Global Air Pollution Dataset               371KB  2022-11-08 14:43:32           1762         52  1.0
# whenamancodes/world-happiness-report                            He..He..He... World Happiness Report 2022  120KB  2022-10-26 09:28:48            790         27  1.0
# maharshipandya/-spotify-tracks-dataset                          🎹 Spotify Tracks Dataset                     8MB  2022-10-22 14:40:15           3056         91  1.0
# whenamancodes/students-performance-in-exams                     Students Performance in Exams                9KB  2022-09-14 15:14:54          18249        334  1.0
# whenamancodes/predict-diabities                                 Predict Diabetes                             9KB  2022-11-09 12:18:49           1382         32  1.0
# iamsouravbanerjee/game-of-thrones-dataset                       Game of Thrones Dataset                     33KB  2022-11-10 11:41:21            369         31  1.0
# jalota/books-dataset                                            Books_dataset                              537KB  2022-11-02 21:02:48            990         25  1.0
# stetsondone/video-game-sales-by-genre                           Video Game Sales by Genre                   12KB  2022-10-31 17:56:01           1239         30  1.0
# marta99/elon-musks-tweets-dataset-2022                          Elon Musk's Tweets Dataset 2022            293KB  2022-10-27 19:10:46            628         32  1.0
# akshaydattatraykhare/car-details-dataset                        Car Details Dataset                         56KB  2022-10-21 06:11:56           3349         58  1.0
# cedricaubin/ai-ml-salaries                                      AI/ML Salaries                              11KB  2022-11-06 11:20:31            571         26  1.0
# thedevastator/predicting-job-titles-from-resumes                Predicting Job Titles from Resumes          40KB  2022-11-05 10:23:35            741         27  1.0

# %%
# !mkdir TitanicKaggleData
# Out:
# mkdir: cannot create directory ‘TitanicKaggleData’: File exists

# %%
cd TitanicKaggleData
# Out:
# /content/gdrive/MyDrive/TitanicKaggleData

# %%
# !kaggle competitions download -c titanic
# Out:
# titanic.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
ls
# Out:
# gender_submission.csv  test.csv  titanic.zip  train.csv

# %% [markdown]
# commenting the next cell cause I have alredy run the notebook and that needs to be done only once

# %%
#!unzip titanic.zip

# %%
import pandas as pd
titanic = pd.read_csv("train.csv")[["Survived", "Pclass", "Age", "Sex"]]
titanic.shape
# Out:
# (891, 4)

# %%
titanic
# Out:
#      Survived  Pclass   Age     Sex
# 0           0       3  22.0    male
# 1           1       1  38.0  female
# 2           1       3  26.0  female
# 3           1       1  35.0  female
# 4           0       3  35.0    male
# ..        ...     ...   ...     ...
# 886         0       2  27.0    male
# 887         1       1  19.0  female
# 888         0       3   NaN  female
# 889         1       1  26.0    male
# 890         0       3  32.0    male
#
# [891 rows x 4 columns]

# %%
titanic["gender"] = titanic["Sex"].map({"male":0, "female":1})

# %%
titanic
# Out:
#      Survived  Pclass   Age     Sex  gender
# 0           0       3  22.0    male       0
# 1           1       1  38.0  female       1
# 2           1       3  26.0  female       1
# 3           1       1  35.0  female       1
# 4           0       3  35.0    male       0
# ..        ...     ...   ...     ...     ...
# 886         0       2  27.0    male       0
# 887         1       1  19.0  female       1
# 888         0       3   NaN  female       1
# 889         1       1  26.0    male       0
# 890         0       3  32.0    male       0
#
# [891 rows x 5 columns]

# %%
titanic.drop("Sex", axis=1, inplace=True)

# %%
titanic
# Out:
#      Survived  Pclass   Age  gender
# 0           0       3  22.0       0
# 1           1       1  38.0       1
# 2           1       3  26.0       1
# 3           1       1  35.0       1
# 4           0       3  35.0       0
# ..        ...     ...   ...     ...
# 886         0       2  27.0       0
# 887         1       1  19.0       1
# 888         0       3   NaN       1
# 889         1       1  26.0       0
# 890         0       3  32.0       0
#
# [891 rows x 4 columns]

# %%
titanic.describe()
# Out:
#          Survived      Pclass         Age      gender
# count  891.000000  891.000000  714.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.352413
# std      0.486592    0.836071   14.526497    0.477990
# min      0.000000    1.000000    0.420000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000
# 50%      0.000000    3.000000   28.000000    0.000000
# 75%      1.000000    3.000000   38.000000    1.000000
# max      1.000000    3.000000   80.000000    1.000000

# %%
titanic.dropna(how="any", axis=0, inplace=True)

# %%
titanic.describe()
# Out:
#          Survived      Pclass         Age      gender
# count  714.000000  714.000000  714.000000  714.000000
# mean     0.406162    2.236695   29.699118    0.365546
# std      0.491460    0.838250   14.526497    0.481921
# min      0.000000    1.000000    0.420000    0.000000
# 25%      0.000000    1.000000   20.125000    0.000000
# 50%      0.000000    2.000000   28.000000    0.000000
# 75%      1.000000    3.000000   38.000000    1.000000
# max      1.000000    3.000000   80.000000    1.000000

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(titanic[["Pclass",	"Age",	
                                                             "gender"]], 
                                                    titanic["Survived"], 
                 train_size=0.75, random_state=123)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((535, 3), (179, 3), (535,), (179,))

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier(max_depth=3, random_state=123)
clf.fit(X_train, y_train)
print("accuracy on training data {:.2}".format(clf.score(X_train, y_train)))
# Out:
# accuracy on training data 0.81

# %%
print("accuracy on test data {:.2}".format(clf.score(X_test, y_test)))
# Out:
# accuracy on test data 0.76

# %%
from sklearn.ensemble import RandomForestClassifier
clf_rf = RandomForestClassifier(max_depth=3)
clf_rf.fit(X_train, y_train)
print("accuracy on training data {:.2}".format(clf_rf.score(X_train, y_train)))
# Out:
# accuracy on training data 0.82

# %%
from sklearn.ensemble import GradientBoostingClassifier
clf_gbd = GradientBoostingClassifier(max_depth=3, random_state=145)
clf_gbd.fit(X_train, y_train)
print("accuracy on training data {:.2}".format(clf_gbd.score(X_train, y_train)))
# Out:
# accuracy on training data 0.88

# %%
print("accuracy on training data {:.2}".format(clf_gbd.score(X_test, y_test)))
# Out:
# accuracy on training data 0.82

# %%
clf_rf.feature_importances_
# Out:
# array([0.27014515, 0.1607211 , 0.56913374])

# %%
import numpy as np
index = np.argsort(clf_rf.feature_importances_)
np.argsort(clf_rf.feature_importances_)
# Out:
# array([1, 0, 2])

# %%
clf_rf.feature_importances_
# Out:
# array([0.27014515, 0.1607211 , 0.56913374])

# %%
columns = np.array(["Pclass",	"Age",	"gender"])[index]

# %%
import pylab as plt
plt.figure(figsize=(5,5))
plt.title("Feature importances")
plt.barh([0, 1, 2], clf_rf.feature_importances_[index],
        color="Steelblue", align="center")
plt.yticks(range(len(columns)), columns);
plt.show()

# %% [markdown]
# # how to get feature importance with uncertainty:
# each trees in the forest makes its own decision and uses the features their own way. So each tree has a different feature importance. Thus we can represent the feature importance overall as the mean of the trees importances, and the spread across the trees as its uncertainty (1 standard deviation of the distribution).
#
# Here is how you do it

# %%
importances = [tree.feature_importances_ for tree in clf_rf.estimators_]
len(clf_rf.estimators_), len(importances)
# Out:
# (100, 100)

# %%
# these the same
np.array(importances).mean(axis=0),  clf_rf.feature_importances_
# Out:
# (array([0.27014515, 0.1607211 , 0.56913374]),
#  array([0.27014515, 0.1607211 , 0.56913374]))

# %%
# this is the error on the feature importance
np.array(importances).std(axis=0)
# Out:
# array([0.17166411, 0.11310389, 0.2280589 ])

# %%
plt.figure(figsize=(5,5))
plt.title("Feature importances")
plt.barh([0, 1, 2], clf_rf.feature_importances_[index],
         xerr=np.array(importances).std(axis=0),
        color="Steelblue", align="center")
plt.yticks(range(len(columns)), columns);
plt.show()
